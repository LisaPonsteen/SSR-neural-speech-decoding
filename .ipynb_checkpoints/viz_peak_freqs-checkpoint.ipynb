# %%
import os
import sys

# Get the absolute path of the directory containing the notebook (notebooks/)
current_dir = os.path.abspath('')

# Add the parent directory (SingleWordProductionDutch/) to the system path
# This allows Python to find 'src'
parent_dir = os.path.dirname(current_dir)
sys.path.append(parent_dir)

import numpy as np
import scipy.signal
from scipy.signal import hilbert
import matplotlib.pyplot as plt
from scipy.signal import welch
from scipy.stats import pearsonr
from pynwb import NWBHDF5IO
from sklearn.metrics import mean_squared_error

import pandas as pd
import numpy.matlib as matlib
import scipy.signal

feat_path = r'./features'
result_path = r'./results'


winL = 0.05
frameshift = 0.01
modelOrder = 4
stepSize = 5
sr=1024
path_bids = '/Users/lisa/Documents/DSAI_year2/Marble/SingleWordProductionDutch/SingleWordProductionDutch-iBIDS'
path_somata = '/Users/lisa/Documents/DSAI_year2/SingleWordProductionDutch-1/somata'

# %%
duration_sec = 2
n_samples = int(duration_sec * sr)
t = np.arange(n_samples) / sr

def get_feat_for_plt(pt, ch_idx):
    hga_stacked = np.load(os.path.join(feat_path,f'{pt}_feat.npy'))
    sspe_stacked = np.load(os.path.join(feat_path,f'{pt}_SSPEfeat.npy'))
    
    feat_hga = hga_stacked[:n_samples, ch_idx].flatten()
    feat_hga_norm = (feat_hga - np.mean(feat_hga)) / np.std(feat_hga) # Normalize for visual comparison (z-score) so they sit on top of each other
    
    somata_results = np.load(os.path.join(path_somata,f'{pt}_somata_results.npy'),allow_pickle=True).item()
    start_col = -1
    for i in range(ch_idx):
        start_col += somata_results[i]['knee_n_osc']
    
    # The number of oscillators for the current channel
    current_n_osc = somata_results[ch_idx]['knee_n_osc']

    # Get the individual oscillator columns for this channel
    individual_oscs = sspe_stacked[:n_samples, start_col : start_col + current_n_osc]
    
    # Sum them for the total SSPE feature
    feat_sspe = np.sum(individual_oscs, axis=1)
    
    if np.std(feat_sspe) ==0:
        print(f"std sspe: {np.std(feat_sspe)}, ch_idx: {ch_idx}")
        print('feat sspe ',feat_sspe)
        feat_sspe_norm = feat_sspe
    feat_sspe_norm = (feat_sspe - np.mean(feat_sspe)) / np.std(feat_sspe)

    
    # Normalize individual oscillators for comparison
    # return these as a list of normalized arrays
    indiv_oscs_norm = []
    for i in range(current_n_osc):
        osc = individual_oscs[:, i]
        if np.std(osc) > 0:
            indiv_oscs_norm.append((osc - np.mean(osc)) / np.std(osc))
        else:
            indiv_oscs_norm.append(osc) # handle zero-variance case

    
    #raw data features
    winL = 0.05
    frameshift = 0.01
    modelOrder = 4
    stepSize = 5
    path_bids = '/Users/lisa/Documents/DSAI_year2/Marble/SingleWordProductionDutch/SingleWordProductionDutch-iBIDS'
    io = NWBHDF5IO(os.path.join(path_bids,pt,'ieeg',f'{pt}_task-wordProduction_ieeg.nwb'), 'r')
    nwbfile = io.read()
    data = nwbfile.acquisition['iEEG'].data[:]
    io.close()
    
    #Small helper function to speed up the hilbert transform by extending the length of data to the next power of 2
    hilbert3 = lambda x: scipy.signal.hilbert(x, scipy.fftpack.next_fast_len(len(x)),axis=0)[:len(x)]
    
    numWindows = int(np.floor((data.shape[0]-winL*sr)/(frameshift*sr)))
        
    #Create feature space
    data = np.abs(hilbert3(data))
    feat = np.zeros((numWindows,data.shape[1]))
    for win in range(numWindows):
        start= int(np.floor((win*frameshift)*sr))
        stop = int(np.floor(start+winL*sr))
        feat[win,:] = np.mean(data[start:stop,:],axis=0)
    
    raw_envelope = feat[:n_samples, ch_idx]
    
    # Normalize for visual comparison so they sit on top of each other
    raw_envelope_norm = (raw_envelope - np.mean(raw_envelope)) / np.std(raw_envelope)

    #get the center frequencies for labeling individual plots
    freqs = somata_results[ch_idx]['freqs']
    
    return raw_envelope_norm, feat_hga_norm, feat_sspe_norm, indiv_oscs_norm, freqs

# %%
pt = 'sub-07'

#ch = [50, 8, 51, 101, 52]
ch = [96, 95, 94, 97, 1] #


for ch_idx in range(1,10):
    raw_envelope_norm, feat_hga_norm, feat_sspe_norm, indiv_oscs_norm, freqs = get_feat_for_plt(pt, ch_idx)
    print(f'channel {ch_idx} for participant {pt}:')

    
    # Correlation measures the linear relationship (timing/envelope similarity)
    corr, _ = pearsonr(feat_hga_norm, raw_envelope_norm)
    # RMSE measures the absolute difference (fit quality)
    rmse = np.sqrt(mean_squared_error(feat_hga_norm, raw_envelope_norm))
    #R-squared
    ss_res = np.sum((raw_envelope_norm - feat_hga_norm) ** 2)
    ss_tot = np.sum((raw_envelope_norm - np.mean(raw_envelope_norm)) ** 2)
    r_sq = 1 - (ss_res / ss_tot)

    print("fit hga to raw envelope")
    print(f'Correlation (r): {corr:.4f}')
    print(f'RMSE:            {rmse:.4f}')
    print(f'R-squared:       {r_sq:.4f}\n')
    


    # now for hga vs raw
    corr, _ = pearsonr(raw_envelope_norm, feat_sspe_norm)
    # RMSE measures the absolute difference (fit quality)
    rmse = np.sqrt(mean_squared_error(raw_envelope_norm, feat_sspe_norm))
    #R-squared
    ss_res = np.sum((raw_envelope_norm - feat_sspe_norm) ** 2)
    ss_tot = np.sum((raw_envelope_norm - np.mean(raw_envelope_norm)) ** 2)
    r_sq = 1 - (ss_res / ss_tot)

    print("fit sspe to raw envelope")
    print(f'Correlation (r): {corr:.4f}')
    print(f'RMSE:            {rmse:.4f}')
    print(f'R-squared:       {r_sq:.4f}\n')

    # Correlation between standard Hilbert HGA and your SSPE version
    r_val, _ = pearsonr(feat_hga_norm, feat_sspe_norm)
    print(f"SSPE vs HGA features correlation: {r_val:.4f}")
    
    
    fig, axes = plt.subplots(4 + len(indiv_oscs_norm), 1, figsize=(10, 8), sharex=True)
    
    # Top: Raw iEEG Feature (Broadband baseline)
    axes[0].plot(t, raw_envelope_norm, color='black', alpha=0.7)
    axes[0].set_title(f'Raw iEEG Envelope')
    axes[0].set_ylabel('amplitude')
    
    # Middle: HGA vs SSPE Similarity
    axes[1].plot(t, feat_hga_norm, label='HG features', color='blue', alpha=0.8)
    axes[1].plot(t, feat_sspe_norm, label='SSPE Oscillator', color='orange', alpha=0.8)
    axes[1].set_title(f'Feature Similarity')
    axes[1].set_ylabel('amplitude')
    axes[1].legend(loc='upper right')

    # HGA vs raw Similarity
    axes[2].plot(t, feat_hga_norm, label='HG Features', color='blue', alpha=0.8)
    axes[2].plot(t, raw_envelope_norm, label='Raw Envelope', color='black', alpha=0.8)
    axes[2].set_title(f'Feature Similarity')
    axes[2].set_ylabel('amplitude')
    axes[2].legend(loc='upper right')

    # raw vs SSPE Similarity
    axes[3].plot(t, feat_sspe_norm, label='SSPE Oscillator', color='orange', alpha=0.8)
    axes[3].plot(t, raw_envelope_norm, label='Raw Envelope', color='black', alpha=0.8)
    axes[3].set_title(f'Feature Similarity')
    axes[3].set_ylabel('amplitude')
    axes[3].legend(loc='upper right')

    # plot individual oscillators
    for i, osc_data in enumerate(indiv_oscs_norm):
        ax_idx = 4 + i
        axes[ax_idx].plot(t, feat_hga_norm, color='black', alpha=0.3, label='HG Features')
        axes[ax_idx].plot(t, osc_data, color='red', alpha=0.8, label=f'Osc {i+1}: {freqs[i]:.1f}Hz')
        
        # Calculate correlation for this specific frequency
        r, _ = pearsonr(feat_hga_norm, osc_data)
        axes[ax_idx].set_title(f'Oscillator {i+1} Fit (r={r:.3f})')
        axes[ax_idx].legend(loc='upper right')
    
    
    plt.tight_layout()
    plt.show()
# Out:
# channel 1 for participant sub-07:
# fit hga to raw envelope
# Correlation (r): 0.1397
# RMSE:            1.3117
# R-squared:       -0.7206
#
# fit sspe to raw envelope
# Correlation (r): 0.4612
# RMSE:            1.0380
# R-squared:       -0.0775
#
# SSPE vs HGA features correlation: 0.1516
# channel 2 for participant sub-07:
# fit hga to raw envelope
# Correlation (r): 0.1963
# RMSE:            1.2678
# R-squared:       -0.6073
#
# fit sspe to raw envelope
# Correlation (r): 0.5694
# RMSE:            0.9280
# R-squared:       0.1388
#
# SSPE vs HGA features correlation: 0.1903
# channel 3 for participant sub-07:
# fit hga to raw envelope
# Correlation (r): 0.0489
# RMSE:            1.3792
# R-squared:       -0.9021
#
# fit sspe to raw envelope
# Correlation (r): 0.6726
# RMSE:            0.8092
# R-squared:       0.3452
#
# SSPE vs HGA features correlation: 0.0420
# channel 4 for participant sub-07:
# fit hga to raw envelope
# Correlation (r): 0.0275
# RMSE:            1.3947
# ...

# %%
import scipy.signal
pt = 'sub-07'
ch_idx = 8
#ch = [50, 8, 51, 101]
ch = [96, 95, 1]

path_bids = '/Users/lisa/Documents/DSAI_year2/Marble/SingleWordProductionDutch/SingleWordProductionDutch-iBIDS'
io = NWBHDF5IO(os.path.join(path_bids,pt,'ieeg',f'{pt}_task-wordProduction_ieeg.nwb'), 'r')
nwbfile = io.read()
data = nwbfile.acquisition['iEEG'].data[:]
io.close()

#remove (harmonics of) line noise just like done with the sspe data
for i in range (0,5):
    sos = scipy.signal.iirfilter(4, [(i*100+49)/(sr/2),(i*100+51)/(sr/2)],btype='bandstop',output='sos')
    data = scipy.signal.sosfiltfilt(sos,data,axis=0)

#for the first 3 channels
osc = [[ 1.57171376, 72.89608773, 30.67527927], [ 1.61172049, 32.21539268, 76.49096605], [ 1.46762755, 32.76762149, 77.56405255, 22.93725585, 12.44592291]
,[ 2.17824134, 27.86930719, 74.8655711 ]]

idx = 0

#for ch_idx in ch:
for ch_idx in range (0,3):
    plt.figure(figsize=(10, 6))
        
    # 1. Compute PSD for Raw Signal
    freqs_raw, psd_raw = welch(data[:, ch_idx], sr, nperseg=1024)
    plt.semilogy(freqs_raw, psd_raw, label='Raw iEEG', color='black', alpha=0.5)
    
    # 2. Compute PSD for SSPE Oscillators 
    # (Assuming you have access to the raw oscillations before absolute value)
    # If you only have features, this plot will look like low-frequency noise.
    sspe_stacked = np.load(os.path.join(feat_path,f'{pt}_SSPEfeat.npy'))
    
    summed_signal = np.zeros(sspe_stacked.shape[0])
    
    nr_osc = len(osc[ch_idx])

    #GET THE RIGHT INDEX AND NR OF OSC FOR THESE CHANNELS
    #might be easier to just pick the first few channels, and look up manually their nr for now (should i later save that info somewhere automatically? is this done correctly in other parts? does the decoder/stacker know??)
    
    for i in range(nr_osc):
        osc_data = sspe_stacked[:, idx + i]
        print (osc_data)
        summed_signal = summed_signal + osc_data  # add all oscillators up so we can check if it that results in the raw signal
        freqs_osc, psd_osc = welch(osc_data, sr, nperseg=1024)
        plt.semilogy(freqs_osc, psd_osc, label=f'SSPE Osc {i+1}', linestyle='--')

    idx += nr_osc
    
    # Compute PSD for the summed signal
    freqs_added, psd_added = welch(summed_signal, sr, nperseg=1024)
    
    plt.semilogy(freqs_added, psd_added, label='Summed oscilators', color='red', alpha=0.5)
    
    plt.title(f'Power Spectral Density Comparison - Channel {ch_idx}')
    plt.xlabel('Frequency (Hz)')
    plt.ylabel('Power/Frequency (dB/Hz)')
    plt.xlim([0, 300]) # Focus on the High-Gamma range
    plt.legend()
    plt.grid(True, which='both', alpha=0.3)
    plt.show()
# Out:
# [ 0.          0.          0.         ... 11.22584974 11.82847544
#  12.45535733]
# [0.         0.         0.         ... 3.07702324 3.28928228 3.40151762]
# [0.         0.         0.         ... 0.52425912 0.60339567 0.77012684]
# [0.         0.         0.         ... 0.44157753 0.41608392 0.43017513]
# [ 0.          0.          0.         ... 13.58474267 11.12244157
#   9.57941916]
# [0.         0.         0.         ... 3.51099307 3.60786693 3.6343213 ]
# [0.         0.         0.         ... 0.66296647 0.61787881 0.74241441]
# [0.         0.         0.         ... 0.42479221 0.40019522 0.41462927]
# [ 0.          0.          0.         ... 16.37214754 11.64676458
#   8.67338768]
# [0.         0.         0.         ... 6.88414574 6.20783645 5.03904646]
# [0.         0.         0.         ... 0.8246244  0.76771347 0.92931083]

# %%
import scipy.signal
pt = 'sub-07'
ch_idx = 8
#ch = [50, 8, 51, 101]
ch = [96, 95, 1]

path_bids = '/Users/lisa/Documents/DSAI_year2/Marble/SingleWordProductionDutch/SingleWordProductionDutch-iBIDS'
io = NWBHDF5IO(os.path.join(path_bids,pt,'ieeg',f'{pt}_task-wordProduction_ieeg.nwb'), 'r')
nwbfile = io.read()
data = nwbfile.acquisition['iEEG'].data[:]
io.close()

#remove (harmonics of) line noise just like done with the sspe data
for i in range (0,5):
    sos = scipy.signal.iirfilter(4, [(i*100+49)/(sr/2),(i*100+51)/(sr/2)],btype='bandstop',output='sos')
    data = scipy.signal.sosfiltfilt(sos,data,axis=0)

#for the first 3 channels
osc = [[ 1.57171376, 72.89608773, 30.67527927], [ 1.61172049, 32.21539268, 76.49096605],
       [ 1.46762755, 32.76762149, 77.56405255, 22.93725585, 12.44592291],
      [ 2.17824134, 27.86930719, 74.8655711 ],
    [1.92596477,  32.81044039,  74.30780164, 20.22396053, 182.98297061, 120.55085829]]

idx = 0

#for ch_idx in ch:
for ch_idx in range (0,5):
    plt.figure(figsize=(10, 6))
        
    # 1. Compute PSD for Raw Signal
    freqs_raw, psd_raw = welch(data[:, ch_idx], sr, nperseg=1024)
    plt.semilogy(freqs_raw, psd_raw, label='Raw iEEG', color='black', alpha=0.5)
    
    # 2. Compute PSD for SSPE Oscillators 
    # (Assuming you have access to the raw oscillations before absolute value)
    # If you only have features, this plot will look like low-frequency noise.
    sspe_stacked = np.load(os.path.join(feat_path,f'{pt}_SSPEfeat.npy'))
    
    nr_osc = len(osc[ch_idx])
    ch_freqs = osc[ch_idx]

    avg_amps = []
    for i in range(len(ch_freqs)):
        # Extract column for this oscillator
        col_data = sspe_stacked[:, idx + i]
        avg_amps.append(np.mean(col_data))
        #print (col_data)
        #print(np.mean(col_data))
            
    idx += nr_osc
    
    # SSPE: Amplitude at each frequency
    # Note: Since PSD is Power (Amplitude^2), we square the mean amplitude for comparison
    plt.scatter(ch_freqs, np.array(avg_amps)**2/ sr, color='red', s=100, zorder=3, label='SSPE Oscillators')
    
    plt.title(f'Power Spectral Density Comparison - Channel {ch_idx}')
    plt.xlabel('Frequency (Hz)')
    plt.ylabel('Power/Frequency (dB/Hz)')
    plt.xlim([0, 300]) # Focus on the High-Gamma range
    plt.legend()
    plt.grid(True, which='both', alpha=0.3)
    plt.show()

# %% [markdown]
# {'freqs': array([ 1.57171376, 72.89608773, 30.67527927]), 'Fs': 1024, 'ampVec': array([0.99555024, 0.9515532 , 0.98708154]), 'sigmaFreqs': array([3.97994972, 0.32491478, 0.21023946]), 'sigmaObs': 1, 'windowSize': 2000, 'lowFreqBand': None}
#
# {'freqs': array([ 1.61172049, 32.21539268, 76.49096605]), 'Fs': 1024, 'ampVec': array([0.9966205 , 0.98246428, 0.96231847]), 'sigmaFreqs': array([4.6353358 , 0.4630824 , 0.18033479]), 'sigmaObs': 1, 'windowSize': 2000, 'lowFreqBand': None}
#
# {'freqs': array([ 1.46762755, 32.76762149, 77.56405255, 22.93725585, 12.44592291]), 'Fs': 1024, 'ampVec': array([0.99758477, 0.98151142, 0.95492596, 0.99302318, 0.99340544]), 'sigmaFreqs': array([2.94761495, 1.34029573, 0.28380785, 0.25067668, 0.56827255]), 'sigmaObs': 1, 'windowSize': 2000, 'lowFreqBand': None}
# 77 hz power is above raw ieeg power, it has ampVec 0.95 and s 0.28
#
# {'freqs': array([ 2.17824134, 27.86930719, 74.8655711 ]), 'Fs': 1024, 'ampVec': array([0.99810887, 0.99059548, 0.95936803]), 'sigmaFreqs': array([3.88624603, 3.76668931, 0.22734596]), 'sigmaObs': 1, 'windowSize': 2000, 'lowFreqBand': None}
#
#
# {'freqs': array([  1.92596477,  32.81044039,  74.30780164,  20.22396053, 182.98297061, 120.55085829]), 'Fs': 1024,
# 'ampVec': array([0.99784674, 0.98744623, 0.96456095, 0.9929969 , 0.88396728, 0.90549209]),
# 'sigmaFreqs': array([2.76033374, 0.79826621, 0.19099963, 0.52275793, 0.1354069 , 0.18351891]), 'sigmaObs': 1, 'windowSize': 2000, 'lowFreqBand': None}
# 74.3 Hz Osc has highest power, ampVec is 0.96 and sigmaFreqs is 0.19 which is is very "stiff" and the model is over-amplifying noise to fit.
# for the 182.9 Hz Osc ampVec is lower (0.88), on the plot we see that the red dot at 182Hz is much closer

# %% [markdown]
# Marble meeting 4/2
#
# Next steps
# 1. make plots in viz_find_peaks including all oscillators from somata.
# 2. include results somata for 'damping a' and 'sigma2' for initParams SSPE model
# 3. build average oscilator framework
# 4. implement the rules below
#
#
# for somata results:
# -use knee_osc, if knee_osc + 1 is hg include that too
# -if knee_osc = 0, look ahead if there is other model with a hg osc. if not, let knee_osc be 1 or 2
#
#
# rule 1
# for channels that don't have a HG oscillator:
# 1.1 substitude all oscillators with a set of average oscillaters from channels that do have hg
# or
# 1.2 add an average hg oscillator set constructed from channels that have hg
#
#
# rule 2
# for all chanels, use set of average oscillaters from channels that do have hg
#
# rule 3
# find with a multivariate approach with a ML model which channels are usefull for the decoder (with bandpass feature data)
# for usefull channels: use rule 1.2
# for useless channels: use rule 2
#
# using correlation with melspec is not a good way. This is because some channels are only usefull in combination with other channels. those can be VERY informative together, but not on their own. so you need a more sophisticated method for that which evaluates the channels as informative as a set

# %% [markdown]
# results
#
# rule 1.1
# sub-06 has mean correlation of 0.794323
# sub-07 has mean correlation of 0.703751
# sub-08 has mean correlation of 0.556479
# sub-09 has mean correlation of 0.484244
# Mean = 0.6348
#
# Rule 1.2
# sub-06 has mean correlation of 0.809089
# sub-07 has mean correlation of 0.703751
# sub-08 has mean correlation of 0.582714
# sub-09 has mean correlation of 0.522065
# Mean = 0.6543
#
# Rule 2
# sub-06 has mean correlation of 0.794323
# sub-07 has mean correlation of 0.677045
# sub-08 has mean correlation of 0.523885
# sub-09 has mean correlation of 0.533890
# Mean = 0.6323
#
# only for sub-09 rule 2 is clearly best. For the rest sub 1.2 is best

# %% [markdown]
# --------------------------
# marble meeting 25/2
#
# next steps:
# make metric of correlation between hga features and sspe features as seen in plot
# debug and figure out why the psd plot oscillators look so similar and not with peaks at center frequencies. they should add together to the raw signal.
#
# try to make more visualization of decoding process so we can look at the actual differences in hga or sspe. maybe look at the audio.
# also because before we look at using rule 3 we want to know how the decoder handels each channels. maybe it already drops out not usefull channels, how would that work?
#
#
# Also plot each osc time series separately to the raw data (like done in the first kind of plots but then for each osc seperately)
#
# experiment: what happens if we only give a subset of features to decoder?
# Now 1 and 6 hz is influenced by not including 20 or 40 hz. Which does matter if we give all to the decoder. so also look into that (how many osc we should include in the template)
#
#
# feedback on the report:
# for me methods shouldnt lean to much on other papers and should be more reproducable, you should at least explain it a bit more instead of just saying oh just look at this paper'. its a fine line

# %% [markdown]
# -------------------------
#
# marble meeting 11/03
#
# task 1: debug and figure out why the psd plot oscillators look so similar and not with peaks at center frequencies. add psd plot of all oscillators and check if they form the complete signal
# bug: initial PSD plots of SSPE features (envelopes) didn't match the raw iEEG because they represent amplitude dynamics, not raw power at frequency.
# Fix:since we only have information on the amplitude and phase and frequency of the entire oscilator, we can just plot dots of the amplitude of that oscillator. doing that gave insight that it while it sometimes fits with psd of raw signal.
# The model can both over and underestimate power, this is because since flagNoFit=True, not allowing the model to estimate and adapt the parameters so the parameters we choose matters a lot.
# Gemini thinks that when overestimating ampVec is too high for some higher freqs (0.95 - 0.99) and that for any frequency >70 Hz, the sigmaFreqs should be at least 1.0 or higher (now for the 77 hz it was 0.28).
#
# next step:
# should set a rule if freq>70 if sigmaFreqs<1 then sigmaFreqs=1 and if freq>70 ampampVecec should be smaller than 0.95 (0r 0.9) and reevaluate how the plots look? or do calibrate the parameters for a short window of time?
# We are keeping flagNoFit=True because we need to validate how the system will perform in a real-time BCI environment where iterative fitting isn't feasible. do you agree?
#
#
# "add psd plot of all oscillators and check if they form the complete signal" not possible with just the amplitudes, decided that also saving the phase and trying to reconstruct was not worth the hassle
# checked if preprocessing (line noise removal) is done and just once and the same exact way. did this, it was correct
#
#
# task 2: plot single seperated oscillators
#
# task 3: make metric of correlation between hga features and sspe features as seen in plot.
# what do we want to compare with what? or: what do we want to maximise??
#
#
# task 4: experiment. what if we only give hg oscillator data to decoder? how many osc should we include in the template?
#
#
#
#
# answers:
# for the psd plots christian said: remember that you dont know if the comparison in amplitude is right. so you cant say that it over or underestimates. aniruhd will know more about the parameters.
# todo: out of own curiosity look how the EM algorithm will fit the parameters, to see if there are any big changes that indicate that we should adapt the initial parameters.
#
#
# for the amplitude-time plots christian said: plotting the individual oscilators on the raw envelope doesnt make much sense. since you then can only see difference in big low freq fluctuations (since they are bigger). comparing individual osc to the hg will give a better view on what little things you do and dont capture.

# %% [markdown]
# meeting 25 march:
#
# task 4: experiment. what if we only give hg oscillator data to decoder? how many osc should we include in the template?
#
# try to make more visualization of decoding process so we can look at the actual differences in hga or sspe. maybe look at the audio.
# also because before we look at using rule 3 we want to know how the decoder handels each channels. maybe it already drops out not usefull channels, how would that work?
#
# todo: out of own curiosity look how the EM algorithm will fit the parameters, to see if there are any big changes that indicate that we should adapt the initial parameters.
