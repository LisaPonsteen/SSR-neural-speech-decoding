# %%
import os
import sys

# Get the absolute path of the directory containing the notebook (notebooks/)
current_dir = os.path.abspath('')

# Add the parent directory (SingleWordProductionDutch/) to the system path
# This allows Python to find 'src'
parent_dir = os.path.dirname(current_dir)
sys.path.append(parent_dir)


# %load_ext autoreload
# %autoreload 2

import numpy as np
import scipy.signal
from scipy.signal import hilbert
import matplotlib.pyplot as plt
from scipy.signal import welch

import pandas as pd
import numpy.matlib as matlib
import scipy
import scipy.stats
import scipy.io.wavfile
import scipy.fftpack
from scipy.stats import pearsonr
from pynwb import NWBHDF5IO

from somata.basic_models import OscillatorModel as Osc
from somata.oscillator_search import IterativeOscillatorModel as IterOsc
from somata.oscillator_search.helper_functions import get_knee
from specparam import SpectralModel

from phaseEM import *
from extract_features import *
from channel_evaluation import *
import config as cfg

# %%
#Get top channels+regions 

#for participant in participants["participant_id"][:2]:
participant = "sub-06"

#Load data
io = NWBHDF5IO(os.path.join(cfg.PATH_BIDS,participant,'ieeg',f'{participant}_task-wordProduction_ieeg.nwb'), 'r')
nwbfile = io.read()
#sEEG
eeg = nwbfile.acquisition['iEEG'].data[:]
eeg_sr = 1024
io.close()

t_segment = 10 #we don't want to take the full 300 seconds for just calibrating, for now, take 10s
n_samples_to_use = int(t_segment * eeg_sr)
eeg = eeg[:n_samples_to_use, :]

eeg = scipy.signal.detrend(eeg, axis=0)

#remove (harmonics of) line noise
for i in range (0,5):
    sos = scipy.signal.iirfilter(4, [(i*100+49)/(eeg_sr/2),(i*100+51)/(eeg_sr/2)],btype='bandstop',output='sos')
    eeg = scipy.signal.sosfiltfilt(sos,eeg,axis=0)

# %%
#Plot raw data of top correlating channel

top_channels, correlation= highest_hg_mel_correlations(participant)

for ch in top_channels:
    print("channel:", ch,", region: ", get_channel_region(participant, ch))


io1 = IterOsc(eeg[:, top_channels[0]], eeg_sr, noise_start=None, osc_range=7)
    
_ = io1.plot_mtm()  # plot multitaper spectrogram and mean spectrum
_ = io1.plot_trace()  # plot raw time trace

'''
for ch in top_channels:
    io1 = IterOsc(eeg[:, ch], eeg_sr, noise_start=None, osc_range=7)
    
    _ = io1.plot_mtm()  # plot multitaper spectrogram and mean spectrum
    _ = io1.plot_trace()  # plot raw time trace
'''
# Out:
# channel: 96 , region:  ctx_lh_S_temporal_transverse
# channel: 95 , region:  Left-Cerebral-White-Matter
# channel: 94 , region:  Left-Cerebral-White-Matter
# channel: 97 , region:  ctx_lh_S_temporal_transverse
# channel: 1 , region:  Left-Amygdala
# Multitaper Spectrogram Properties:
#      Spectral Resolution: 4.0Hz
#      Window Length: 1.0s
#      Window Step: 0.0498046875s
#      Time Half-Bandwidth Product: 2
#      Number of Tapers: 3
#      Frequency Range: 0-512.0Hz
#      NFFT: 16384
#      Detrend: constant
# /Users/lisa/Library/Python/3.9/lib/python/site-packages/somata/multitaper/multitaper_spectrogram_python.py:297: UserWarning: Window step size is not divisible by sampling frequency. Adjusting window step size to 0.0498046875 seconds
#   warnings.warn('Window step size is not divisible by sampling frequency. Adjusting window step size to ' +
#  Multitaper compute time: 0.25 seconds
# '\nfor ch in top_channels:\n    io1 = IterOsc(eeg[:, ch], eeg_sr, noise_start=None, osc_range=7)\n    \n    _ = io1.plot_mtm()  # plot multitaper spectrogram and mean spectrum\n    _ = io1.plot_trace()  # plot raw time trace\n'

# %%
#SOMATA peak detection
from joblib import Parallel, delayed

channel_results={}
j=0

path_somata =  '/Users/lisa/Documents/DSAI_year2/SingleWordProductionDutch-1/somata'

#for ch in top_channels:

n_channels = eeg.shape[1]

for ch in range(n_channels):
# -run IterOsc for the channel -
    io1 = IterOsc(eeg[:, ch], eeg_sr, noise_start=None, osc_range=7)
    io1.iterate(freq_res=1, plot_fit=False, verbose=True) 

    # find knee index
    ll_vec = io1.ll
    knee_idx = get_knee(ll_vec)
    
    # take model of knee index
    best_model_for_ch = io1.get_knee_osc()

    #adapt the optimal model_idx if it returns 0 as optimal (by seeing if it can find a hg osc)
    if knee_idx == 0: #go through each iteration, when finding one with a hg osc, pick that as best
        for i, model in enumerate(io1.fitted_osc[knee_idx+1:], start=knee_idx+1): #io1.fitted_osc contains the Osc objects for each step of the search (1 oscillator, then 2, then 3, etc.)
            last_freq = model.freq[-1]
            
            # find for a last frequency is in HG range, to pick that as best model
            if last_freq >= 70 and last_freq<=170:
                best_model_for_ch = model
                knee_idx = i
                break
        #if didn't find a hg osc, force knee_idx to 2
        if knee_idx == 0:
            knee_idx = 2
        print(f'changed knee_idx from 0 to {knee_idx}')


    # if the next model (at knee_idx+1)gives us a frequency in HG range we don't track yet
    if knee_idx + 1 < len(io1.fitted_osc): #first check if we're not already at the last iteration
        last_freq_next_model = io1.fitted_osc[knee_idx+1].freq[-1]
        if 70 <= last_freq_next_model <= 170:
            # ceck: Is this new frequency at least 5Hz away from all current frequencies? to ensure it's not redundant with any existing oscillator
            freq_diffs = np.abs(best_model_for_ch.freq - last_freq_next_model)
            if np.all(freq_diffs > 5):
                knee_idx = knee_idx + 1
                best_model_for_ch =  io1.fitted_osc[knee_idx]
                print(f'found another hg freq at knee_idx +1 (={knee_idx})')
                print(f' freqs: {best_model_for_ch.freq}')
                assert len(best_model_for_ch.freq) == knee_idx +1, 'invalid kneeidx update'

    
    #Examine the final oscillator model selected by the iOsc+ algorithm.
    print(best_model_for_ch)

    #Plot log-likelihood and the selected model (may not be the highest likelihood).
    #_ = io1.plot_log_likelihoods()
    
    #save results for optimal model
    channel_results[j] = { #channel_results[ch_idx] = {
        'channel': ch,
        'knee_n_osc': knee_idx + 1,
        'logL': ll_vec[knee_idx],
        'freqs': best_model_for_ch.freq,
        'damping': best_model_for_ch.a,
        'sigma2': best_model_for_ch.sigma2, 
        'obs_noise_R': best_model_for_ch.R 
    }
    print("channel", ch)
    print(channel_results[j])
    _ = io1.plot_log_likelihoods()
    j=j+1


np.save(os.path.join(path_somata,f'{participant}_somata_results.npy'), channel_results)
# Out:
# EM learning on the initial oscillator
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.2672508431942233), 'Q_sigma2': 'MLE'}
# Iteration 0 completed:
# <Osc object at 0x17a8b62b0>
#  nstate   = 2     ncomp    = 1
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<6460>]
#  F  .shape = (2, 2)     Q  .shape = (2, 2)
#  mu0.shape = (2, 1)     S0 .shape = (2, 2)
#  G  .shape = (1, 2)     R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.994]
#  freq Hz   = [1.5]
#  sigma2    = [5.641]
#  obs noise R = [[0.205]]
#  dc index  = None
#
# AR: add freq = 67.49 Hz, add radius = 0.729, add sigma2 = 0.297
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.2672508431942233), 'Q_sigma2': 'MLE'}
# Iteration 1 completed:
# <Osc object at 0x17a8b62b0>
#  nstate   = 4     ncomp    = 2
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<6850>, Osc(0)<6610>]
#  F  .shape = (4, 4)     Q  .shape = (4, 4)
#  mu0.shape = (4, 1)     S0 .shape = (4, 4)
#  G  .shape = (1, 4)     R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.995 0.953]
#  freq Hz   = [ 1.63 71.11]
#  sigma2    = [4.683 0.306]
#  obs noise R = [[0.204]]
#  dc index  = None
#
# AR: add freq = 33.28 Hz, add radius = 0.851, add sigma2 = 0.183
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.2672508431942233), 'Q_sigma2': 'MLE'}
# Iteration 2 completed:
# <Osc object at 0x17a8b62b0>
#  nstate   = 6     ncomp    = 3
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<a070>, Osc(0)<a040>, Osc(0)<9040>]
#  F  .shape = (6, 6)     Q  .shape = (6, 6)
#  mu0.shape = (6, 1)     S0 .shape = (6, 6)
#  G  .shape = (1, 6)     R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.996 0.952 0.987]
#  freq Hz   = [ 1.57 72.9  30.68]
#  sigma2    = [3.98  0.325 0.21 ]
#  obs noise R = [[0.205]]
#  dc index  = None
#
# AR: add freq = 25.31 Hz, add radius = 0.770, add sigma2 = 0.201
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.2672508431942233), 'Q_sigma2': 'MLE'}
# Iteration 3 completed:
# <Osc object at 0x17a8b62b0>
#  nstate   = 8     ncomp    = 4
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<b9d0>, Osc(0)<b910>, Osc(0)<b9a0>, Osc(0)<b850>]
#  F  .shape = (8, 8)     Q  .shape = (8, 8)
#  mu0.shape = (8, 1)     S0 .shape = (8, 8)
#  G  .shape = (1, 8)     R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.996 0.949 0.988 0.87 ]
#  freq Hz   = [ 1.56 72.54 28.34 30.6 ]
#  sigma2    = [3.69  0.353 0.26  0.18 ]
#  obs noise R = [[0.205]]
#  dc index  = None
#
# AR: add freq = 23.66 Hz, add radius = 0.761, add sigma2 = 0.219
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.2672508431942233), 'Q_sigma2': 'MLE'}
# Iteration 4 completed:
# <Osc object at 0x17a8b62b0>
#  nstate   = 10    ncomp    = 5
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<c790>, Osc(0)<c910>, Osc(0)<c8e0>, Osc(0)<c820>, Osc(0)<c760>]
#  F  .shape = (10, 10)   Q  .shape = (10, 10)
#  mu0.shape = (10, 1)    S0 .shape = (10, 10)
#  G  .shape = (1, 10)    R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.996 0.947 0.987 0.981 0.85 ]
#  freq Hz   = [ 1.57 73.96 26.09 37.47 27.29]
#  sigma2    = [3.296 0.364 0.29  0.178 0.191]
#  obs noise R = [[0.205]]
#  dc index  = None
#
# AR: add freq = 211.99 Hz, add radius = 0.748, add sigma2 = 0.145
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.2672508431942233), 'Q_sigma2': 'MLE'}
# Iteration 5 completed:
# <Osc object at 0x17a8b62b0>
#  nstate   = 12    ncomp    = 6
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<a4c0>, Osc(0)<a4f0>, Osc(0)<a1c0>, Osc(0)<a2b0>, Osc(0)<a460>, Osc(0)<a1f0>]
#  F  .shape = (12, 12)   Q  .shape = (12, 12)
#  mu0.shape = (12, 1)    S0 .shape = (12, 12)
#  G  .shape = (1, 12)    R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.997 0.95  0.987 0.983 0.923 0.869]
#  freq Hz   = [  1.63  73.93  24.66  37.2   28.28 179.41]
#  sigma2    = [2.704 0.356 0.301 0.176 0.168 0.121]
#  obs noise R = [[0.201]]
#  dc index  = None
#
# AR: add freq = 129.55 Hz, add radius = 0.777, add sigma2 = 0.170
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.2672508431942233), 'Q_sigma2': 'MLE'}
# Iteration 6 completed:
# <Osc object at 0x17a8b62b0>
#  nstate   = 14    ncomp    = 7
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<1700>, Osc(0)<1d00>, Osc(0)<1ee0>, Osc(0)<14f0>, Osc(0)<1c10>, Osc(0)<1a30>, Osc(0)<fa90>]
#  F  .shape = (14, 14)   Q  .shape = (14, 14)
#  mu0.shape = (14, 1)    S0 .shape = (14, 14)
#  G  .shape = (1, 14)    R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.997 0.957 0.994 0.983 0.991 0.878 0.908]
#  freq Hz   = [  1.39  71.29  13.78  38.05  27.07 184.23 122.02]
#  sigma2    = [1.95  0.323 0.319 0.174 0.159 0.104 0.149]
#  obs noise R = [[0.201]]
#  dc index  = None
#
# <Osc object at 0x17a9a92e0>
#  nstate   = 6     ncomp    = 3
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<90d0>, Osc(0)<6bb0>, Osc(0)<6610>]
#  F  .shape = (6, 6)     Q  .shape = (6, 6)
#  mu0.shape = (6, 1)     S0 .shape = (6, 6)
#  G  .shape = (1, 6)     R  .shape = (1, 1)
#  y  .shape = None       Fs = 1024.0 Hz
#  damping a = [0.996 0.952 0.987]
#  freq Hz   = [ 1.57 72.9  30.68]
#  sigma2    = [3.98  0.325 0.21 ]
#  obs noise R = [[0.205]]
#  dc index  = None
#
# channel 0
# {'channel': 0, 'knee_n_osc': np.int64(3), 'logL': np.float64(-23274.39083299223), 'freqs': array([ 1.57171376, 72.89608773, 30.67527927]), 'damping': array([0.99555024, 0.9515532 , 0.98708154]), 'sigma2': array([3.97994972, 0.32491478, 0.21023946]), 'obs_noise_R': array([[0.20502872]])}
# EM learning on the initial oscillator
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.30601199595167117), 'Q_sigma2': 'MLE'}
# Iteration 0 completed:
# <Osc object at 0x17a8f69d0>
#  nstate   = 2     ncomp    = 1
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<eb20>]
#  F  .shape = (2, 2)     Q  .shape = (2, 2)
#  mu0.shape = (2, 1)     S0 .shape = (2, 2)
#  G  .shape = (1, 2)     R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.996]
#  freq Hz   = [1.56]
#  sigma2    = [6.468]
#  obs noise R = [[0.232]]
#  dc index  = None
#
# AR: add freq = 38.34 Hz, add radius = 0.695, add sigma2 = 0.406
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.30601199595167117), 'Q_sigma2': 'MLE'}
# Iteration 1 completed:
# <Osc object at 0x17a8f69d0>
#  nstate   = 4     ncomp    = 2
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<5160>, Osc(0)<65b0>]
#  F  .shape = (4, 4)     Q  .shape = (4, 4)
#  mu0.shape = (4, 1)     S0 .shape = (4, 4)
#  G  .shape = (1, 4)     R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.996 0.972]
#  freq Hz   = [ 1.6  41.44]
#  sigma2    = [5.495 0.398]
#  obs noise R = [[0.232]]
#  dc index  = None
#
# AR: add freq = 85.78 Hz, add radius = 0.799, add sigma2 = 0.164
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.30601199595167117), 'Q_sigma2': 'MLE'}
# Iteration 2 completed:
# <Osc object at 0x17a8f69d0>
#  nstate   = 6     ncomp    = 3
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<a1c0>, Osc(0)<a070>, Osc(0)<c6a0>]
#  F  .shape = (6, 6)     Q  .shape = (6, 6)
#  mu0.shape = (6, 1)     S0 .shape = (6, 6)
#  G  .shape = (1, 6)     R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.997 0.982 0.962]
#  freq Hz   = [ 1.61 32.22 76.49]
#  sigma2    = [4.635 0.463 0.18 ]
#  obs noise R = [[0.232]]
#  dc index  = None
#
# AR: add freq = 203.30 Hz, add radius = 0.764, add sigma2 = 0.183
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.30601199595167117), 'Q_sigma2': 'MLE'}
# Iteration 3 completed:
# <Osc object at 0x17a8f69d0>
#  nstate   = 8     ncomp    = 4
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<e5b0>, Osc(0)<e5e0>, Osc(0)<e550>, Osc(0)<e6a0>]
#  F  .shape = (8, 8)     Q  .shape = (8, 8)
#  mu0.shape = (8, 1)     S0 .shape = (8, 8)
#  G  .shape = (1, 8)     R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.997 0.983 0.964 0.867]
#  freq Hz   = [  1.68  31.65  74.94 172.25]
#  sigma2    = [3.931 0.52  0.193 0.142]
#  obs noise R = [[0.228]]
#  dc index  = None
#
# AR: add freq = 119.39 Hz, add radius = 0.783, add sigma2 = 0.159
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.30601199595167117), 'Q_sigma2': 'MLE'}
# Iteration 4 completed:
# <Osc object at 0x17a8f69d0>
#  nstate   = 10    ncomp    = 5
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<e9d0>, Osc(0)<eac0>, Osc(0)<eaf0>, Osc(0)<eb80>, Osc(0)<ebe0>]
#  F  .shape = (10, 10)   Q  .shape = (10, 10)
#  mu0.shape = (10, 1)    S0 .shape = (10, 10)
#  G  .shape = (1, 10)    R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.997 0.983 0.964 0.872 0.905]
#  freq Hz   = [  1.7   31.26  73.04 173.55 113.11]
#  sigma2    = [3.627 0.552 0.191 0.116 0.139]
#  obs noise R = [[0.227]]
#  dc index  = None
#
# AR: add freq = 219.26 Hz, add radius = 0.761, add sigma2 = 0.116
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.30601199595167117), 'Q_sigma2': 'MLE'}
# Iteration 5 completed:
# <Osc object at 0x17a8f69d0>
#  nstate   = 12    ncomp    = 6
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<0040>, Osc(0)<00d0>, Osc(0)<0130>, Osc(0)<0190>, Osc(0)<01f0>, Osc(0)<0250>]
#  F  .shape = (12, 12)   Q  .shape = (12, 12)
#  mu0.shape = (12, 1)    S0 .shape = (12, 12)
#  G  .shape = (1, 12)    R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.997 0.982 0.965 0.87  0.919 0.791]
#  freq Hz   = [  1.7   31.13  72.57 167.83 107.86 192.05]
#  sigma2    = [3.528 0.57  0.185 0.095 0.122 0.088]
#  obs noise R = [[0.226]]
#  dc index  = None
#
# AR: add freq = 81.81 Hz, add radius = 0.698, add sigma2 = 0.058
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.30601199595167117), 'Q_sigma2': 'MLE'}
# Iteration 6 completed:
# <Osc object at 0x17a8f69d0>
#  nstate   = 14    ncomp    = 7
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<0430>, Osc(0)<0760>, Osc(0)<0700>, Osc(0)<0820>, Osc(0)<0880>, Osc(0)<08e0>, Osc(0)<0940>]
#  F  .shape = (14, 14)   Q  .shape = (14, 14)
#  mu0.shape = (14, 1)    S0 .shape = (14, 14)
#  G  .shape = (1, 14)    R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.997 0.982 0.965 0.87  0.927 0.846 0.735]
#  freq Hz   = [  1.7   31.06  72.26 163.39 103.5  185.39  78.58]
#  sigma2    = [3.54  0.582 0.178 0.082 0.11  0.075 0.053]
#  obs noise R = [[0.226]]
#  dc index  = None
#
# <Osc object at 0x17a875160>
#  nstate   = 6     ncomp    = 3
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<65b0>, Osc(0)<e3a0>, Osc(0)<e460>]
#  F  .shape = (6, 6)     Q  .shape = (6, 6)
#  mu0.shape = (6, 1)     S0 .shape = (6, 6)
#  G  .shape = (1, 6)     R  .shape = (1, 1)
#  y  .shape = None       Fs = 1024.0 Hz
#  damping a = [0.997 0.982 0.962]
#  freq Hz   = [ 1.61 32.22 76.49]
#  sigma2    = [4.635 0.463 0.18 ]
#  obs noise R = [[0.232]]
#  dc index  = None
#
# channel 1
# {'channel': 1, 'knee_n_osc': np.int64(3), 'logL': np.float64(-23978.38538354373), 'freqs': array([ 1.61172049, 32.21539268, 76.49096605]), 'damping': array([0.9966205 , 0.98246428, 0.96231847]), 'sigma2': array([4.6353358 , 0.4630824 , 0.18033479]), 'obs_noise_R': array([[0.23225087]])}
# EM learning on the initial oscillator
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.32570261593931893), 'Q_sigma2': 'MLE'}
# Iteration 0 completed:
# <Osc object at 0x17a8cbaf0>
#  nstate   = 2     ncomp    = 1
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<6a00>]
#  F  .shape = (2, 2)     Q  .shape = (2, 2)
#  mu0.shape = (2, 1)     S0 .shape = (2, 2)
#  G  .shape = (1, 2)     R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.994]
#  freq Hz   = [2.05]
#  sigma2    = [8.208]
#  obs noise R = [[0.249]]
#  dc index  = None
#
# AR: add freq = 37.30 Hz, add radius = 0.873, add sigma2 = 0.365
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.32570261593931893), 'Q_sigma2': 'MLE'}
# Iteration 1 completed:
# <Osc object at 0x17a8cbaf0>
#  nstate   = 4     ncomp    = 2
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<eb80>, Osc(0)<e9a0>]
#  F  .shape = (4, 4)     Q  .shape = (4, 4)
#  mu0.shape = (4, 1)     S0 .shape = (4, 4)
#  G  .shape = (1, 4)     R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.996 0.99 ]
#  freq Hz   = [ 1.81 32.  ]
#  sigma2    = [6.102 0.617]
#  obs noise R = [[0.248]]
#  dc index  = None
#
# AR: add freq = 85.78 Hz, add radius = 0.779, add sigma2 = 0.264
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.32570261593931893), 'Q_sigma2': 'MLE'}
# Iteration 2 completed:
# <Osc object at 0x17a8cbaf0>
#  nstate   = 6     ncomp    = 3
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<03d0>, Osc(0)<04f0>, Osc(0)<0640>]
#  F  .shape = (6, 6)     Q  .shape = (6, 6)
#  mu0.shape = (6, 1)     S0 .shape = (6, 6)
#  G  .shape = (1, 6)     R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.997 0.987 0.955]
#  freq Hz   = [ 1.83 30.39 77.69]
#  sigma2    = [4.495 1.037 0.284]
#  obs noise R = [[0.247]]
#  dc index  = None
#
# AR: add freq = 23.19 Hz, add radius = 0.784, add sigma2 = 0.319
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.32570261593931893), 'Q_sigma2': 'MLE'}
# Iteration 3 completed:
# <Osc object at 0x17a8cbaf0>
#  nstate   = 8     ncomp    = 4
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<6ee0>, Osc(0)<6f10>, Osc(0)<6e80>, Osc(0)<6fd0>]
#  F  .shape = (8, 8)     Q  .shape = (8, 8)
#  mu0.shape = (8, 1)     S0 .shape = (8, 8)
#  G  .shape = (1, 8)     R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.997 0.985 0.954 0.895]
#  freq Hz   = [ 1.79 29.11 77.03 26.68]
#  sigma2    = [3.856 1.41  0.291 0.269]
#  obs noise R = [[0.247]]
#  dc index  = None
#
# AR: add freq = 12.46 Hz, add radius = 0.754, add sigma2 = 0.811
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.32570261593931893), 'Q_sigma2': 'MLE'}
# Iteration 4 completed:
# <Osc object at 0x17a8cbaf0>
#  nstate   = 10    ncomp    = 5
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<0340>, Osc(0)<0430>, Osc(0)<0460>, Osc(0)<04f0>, Osc(0)<0550>]
#  F  .shape = (10, 10)   Q  .shape = (10, 10)
#  mu0.shape = (10, 1)    S0 .shape = (10, 10)
#  G  .shape = (1, 10)    R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.998 0.982 0.955 0.993 0.993]
#  freq Hz   = [ 1.47 32.77 77.56 22.94 12.45]
#  sigma2    = [2.948 1.34  0.284 0.251 0.568]
#  obs noise R = [[0.247]]
#  dc index  = None
#
# AR: add freq = 202.74 Hz, add radius = 0.767, add sigma2 = 0.277
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.32570261593931893), 'Q_sigma2': 'MLE'}
# Iteration 5 completed:
# <Osc object at 0x17a8cbaf0>
#  nstate   = 12    ncomp    = 6
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<0760>, Osc(0)<0a00>, Osc(0)<0a60>, Osc(0)<0ac0>, Osc(0)<0b20>, Osc(0)<0b80>]
#  F  .shape = (12, 12)   Q  .shape = (12, 12)
#  mu0.shape = (12, 1)    S0 .shape = (12, 12)
#  G  .shape = (1, 12)    R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.998 0.985 0.957 0.994 0.995 0.869]
#  freq Hz   = [  1.39  33.38  78.16  21.82  10.64 173.87]
#  sigma2    = [1.81  1.041 0.317 0.259 0.561 0.211]
#  obs noise R = [[0.242]]
#  dc index  = None
#
# AR: add freq = 9.33 Hz, add radius = 0.717, add sigma2 = 1.112
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.32570261593931893), 'Q_sigma2': 'MLE'}
# Iteration 6 completed:
# <Osc object at 0x17a8cbaf0>
#  nstate   = 14    ncomp    = 7
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<0d30>, Osc(0)<0ee0>, Osc(0)<0460>, Osc(0)<0fa0>, Osc(0)<c040>, Osc(0)<c0a0>, Osc(0)<c100>]
#  F  .shape = (14, 14)   Q  .shape = (14, 14)
#  mu0.shape = (14, 1)    S0 .shape = (14, 14)
#  G  .shape = (1, 14)    R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.999 0.986 0.956 0.994 0.995 0.875 0.946]
#  freq Hz   = [  1.36  33.42  77.46  21.94  10.38 171.66  14.18]
#  sigma2    = [1.618 0.901 0.328 0.271 0.581 0.177 0.581]
#  obs noise R = [[0.242]]
#  dc index  = None
#
# <Osc object at 0x171ad0130>
#  nstate   = 10    ncomp    = 5
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<03a0>, Osc(0)<06a0>, Osc(0)<08e0>, Osc(0)<0880>, Osc(0)<07c0>]
#  F  .shape = (10, 10)   Q  .shape = (10, 10)
#  mu0.shape = (10, 1)    S0 .shape = (10, 10)
#  G  .shape = (1, 10)    R  .shape = (1, 1)
#  y  .shape = None       Fs = 1024.0 Hz
#  damping a = [0.998 0.982 0.955 0.993 0.993]
#  freq Hz   = [ 1.47 32.77 77.56 22.94 12.45]
#  sigma2    = [2.948 1.34  0.284 0.251 0.568]
#  obs noise R = [[0.247]]
#  dc index  = None
#
# channel 2
# {'channel': 2, 'knee_n_osc': np.int64(5), 'logL': np.float64(-24436.220217212758), 'freqs': array([ 1.46762755, 32.76762149, 77.56405255, 22.93725585, 12.44592291]), 'damping': array([0.99758477, 0.98151142, 0.95492596, 0.99302318, 0.99340544]), 'sigma2': array([2.94761495, 1.34029573, 0.28380785, 0.25067668, 0.56827255]), 'obs_noise_R': array([[0.24714353]])}
# EM learning on the initial oscillator
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.2830022910272824), 'Q_sigma2': 'MLE'}
# Iteration 0 completed:
# <Osc object at 0x179dbc130>
#  nstate   = 2     ncomp    = 1
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<c580>]
#  F  .shape = (2, 2)     Q  .shape = (2, 2)
#  mu0.shape = (2, 1)     S0 .shape = (2, 2)
#  G  .shape = (1, 2)     R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.994]
#  freq Hz   = [3.7]
#  sigma2    = [13.966]
#  obs noise R = [[0.231]]
#  dc index  = None
#
# AR: add freq = 34.53 Hz, add radius = 0.934, add sigma2 = 0.737
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.2830022910272824), 'Q_sigma2': 'MLE'}
# Iteration 1 completed:
# <Osc object at 0x179dbc130>
#  nstate   = 4     ncomp    = 2
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<e790>, Osc(0)<eb80>]
#  F  .shape = (4, 4)     Q  .shape = (4, 4)
#  mu0.shape = (4, 1)     S0 .shape = (4, 4)
#  G  .shape = (1, 4)     R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.998 0.991]
#  freq Hz   = [ 2.25 28.95]
#  sigma2    = [5.12  3.198]
#  obs noise R = [[0.222]]
#  dc index  = None
#
# AR: add freq = 79.97 Hz, add radius = 0.737, add sigma2 = 0.260
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.2830022910272824), 'Q_sigma2': 'MLE'}
# Iteration 2 completed:
# <Osc object at 0x179dbc130>
#  nstate   = 6     ncomp    = 3
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<02e0>, Osc(0)<0bb0>, Osc(0)<0220>]
#  F  .shape = (6, 6)     Q  .shape = (6, 6)
#  mu0.shape = (6, 1)     S0 .shape = (6, 6)
#  G  .shape = (1, 6)     R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.998 0.991 0.959]
#  freq Hz   = [ 2.18 27.87 74.87]
#  sigma2    = [3.886 3.767 0.227]
#  obs noise R = [[0.221]]
#  dc index  = None
#
# AR: add freq = 19.11 Hz, add radius = 0.783, add sigma2 = 0.981
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.2830022910272824), 'Q_sigma2': 'MLE'}
# Iteration 3 completed:
# <Osc object at 0x179dbc130>
#  nstate   = 8     ncomp    = 4
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<3640>, Osc(0)<3670>, Osc(0)<35e0>, Osc(0)<3730>]
#  F  .shape = (8, 8)     Q  .shape = (8, 8)
#  mu0.shape = (8, 1)     S0 .shape = (8, 8)
#  G  .shape = (1, 8)     R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.998 0.99  0.968 0.996]
#  freq Hz   = [ 2.18 33.03 71.78 21.38]
#  sigma2    = [3.689 2.372 0.211 0.731]
#  obs noise R = [[0.22]]
#  dc index  = None
#
# AR: add freq = 98.81 Hz, add radius = 0.730, add sigma2 = 0.178
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.2830022910272824), 'Q_sigma2': 'MLE'}
# Iteration 4 completed:
# <Osc object at 0x179dbc130>
#  nstate   = 10    ncomp    = 5
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<3a60>, Osc(0)<3b50>, Osc(0)<3b80>, Osc(0)<3c10>, Osc(0)<3c70>]
#  F  .shape = (10, 10)   Q  .shape = (10, 10)
#  mu0.shape = (10, 1)    S0 .shape = (10, 10)
#  G  .shape = (1, 10)    R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.998 0.991 0.969 0.996 0.858]
#  freq Hz   = [ 2.19 33.58 70.79 21.66 99.01]
#  sigma2    = [3.831 1.769 0.21  0.874 0.156]
#  obs noise R = [[0.22]]
#  dc index  = None
#
# AR: add freq = 198.90 Hz, add radius = 0.723, add sigma2 = 0.387
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.2830022910272824), 'Q_sigma2': 'MLE'}
# Iteration 5 completed:
# <Osc object at 0x179dbc130>
#  nstate   = 12    ncomp    = 6
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<3ca0>, Osc(0)<3c40>, Osc(0)<3670>, Osc(0)<3640>, Osc(0)<3d60>, Osc(0)<3e80>]
#  F  .shape = (12, 12)   Q  .shape = (12, 12)
#  mu0.shape = (12, 1)    S0 .shape = (12, 12)
#  G  .shape = (1, 12)    R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.998 0.992 0.972 0.995 0.948 0.812]
#  freq Hz   = [  2.19  33.74  67.2   21.67  92.08 151.54]
#  sigma2    = [3.478 1.493 0.197 0.968 0.139 0.218]
#  obs noise R = [[0.218]]
#  dc index  = None
#
# AR: add freq = 207.87 Hz, add radius = 0.747, add sigma2 = 0.238
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.2830022910272824), 'Q_sigma2': 'MLE'}
# Iteration 6 completed:
# <Osc object at 0x179dbc130>
#  nstate   = 14    ncomp    = 7
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<3ee0>, Osc(0)<3f10>, Osc(0)<3f70>, Osc(0)<3df0>, Osc(0)<3eb0>, Osc(0)<f070>, Osc(0)<f0a0>]
#  F  .shape = (14, 14)   Q  .shape = (14, 14)
#  mu0.shape = (14, 1)    S0 .shape = (14, 14)
#  G  .shape = (1, 14)    R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.998 0.993 0.974 0.995 0.961 0.842 0.773]
#  freq Hz   = [  2.18  33.81  65.06  21.68  85.88 134.69 167.2 ]
#  sigma2    = [3.407 1.394 0.18  1.034 0.126 0.158 0.151]
#  obs noise R = [[0.217]]
#  dc index  = None
#
# found another hg freq at knee_idx +1 (=2)
#  freqs: [ 2.17824134 27.86930719 74.8655711 ]
# <Osc object at 0x171b0e9a0>
#  nstate   = 6     ncomp    = 3
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<3430>, Osc(0)<34f0>, Osc(0)<3520>]
#  F  .shape = (6, 6)     Q  .shape = (6, 6)
#  mu0.shape = (6, 1)     S0 .shape = (6, 6)
#  G  .shape = (1, 6)     R  .shape = (1, 1)
#  y  .shape = None       Fs = 1024.0 Hz
#  damping a = [0.998 0.991 0.959]
#  freq Hz   = [ 2.18 27.87 74.87]
#  sigma2    = [3.886 3.767 0.227]
#  obs noise R = [[0.221]]
#  dc index  = None
#
# channel 3
# {'channel': 3, 'knee_n_osc': np.int64(3), 'logL': np.float64(-26179.813115468787), 'freqs': array([ 2.17824134, 27.86930719, 74.8655711 ]), 'damping': array([0.99810887, 0.99059548, 0.95936803]), 'sigma2': array([3.88624603, 3.76668931, 0.22734596]), 'obs_noise_R': array([[0.22114154]])}
# EM learning on the initial oscillator
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.271013296855248), 'Q_sigma2': 'MLE'}
# Iteration 0 completed:
# <Osc object at 0x171ad04f0>
#  nstate   = 2     ncomp    = 1
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<6ca0>]
#  F  .shape = (2, 2)     Q  .shape = (2, 2)
#  mu0.shape = (2, 1)     S0 .shape = (2, 2)
#  G  .shape = (1, 2)     R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.995]
#  freq Hz   = [2.36]
#  sigma2    = [8.135]
#  obs noise R = [[0.214]]
#  dc index  = None
#
# AR: add freq = 35.73 Hz, add radius = 0.871, add sigma2 = 0.375
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.271013296855248), 'Q_sigma2': 'MLE'}
# Iteration 1 completed:
# <Osc object at 0x171ad04f0>
#  nstate   = 4     ncomp    = 2
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<f190>, Osc(0)<e580>]
#  F  .shape = (4, 4)     Q  .shape = (4, 4)
#  mu0.shape = (4, 1)     S0 .shape = (4, 4)
#  G  .shape = (1, 4)     R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.996 0.99 ]
#  freq Hz   = [ 2.05 31.33]
#  sigma2    = [6.109 0.608]
#  obs noise R = [[0.213]]
#  dc index  = None
#
# AR: add freq = 81.49 Hz, add radius = 0.759, add sigma2 = 0.175
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.271013296855248), 'Q_sigma2': 'MLE'}
# Iteration 2 completed:
# <Osc object at 0x171ad04f0>
#  nstate   = 6     ncomp    = 3
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<3d30>, Osc(0)<3c70>, Osc(0)<3dc0>]
#  F  .shape = (6, 6)     Q  .shape = (6, 6)
#  mu0.shape = (6, 1)     S0 .shape = (6, 6)
#  G  .shape = (1, 6)     R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.997 0.988 0.958]
#  freq Hz   = [ 2.01 29.37 79.43]
#  sigma2    = [4.795 1.034 0.184]
#  obs noise R = [[0.212]]
#  dc index  = None
#
# AR: add freq = 17.81 Hz, add radius = 0.751, add sigma2 = 0.584
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.271013296855248), 'Q_sigma2': 'MLE'}
# Iteration 3 completed:
# <Osc object at 0x171ad04f0>
#  nstate   = 8     ncomp    = 4
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<37f0>, Osc(0)<3fa0>, Osc(0)<39a0>, Osc(0)<3b80>]
#  F  .shape = (8, 8)     Q  .shape = (8, 8)
#  mu0.shape = (8, 1)     S0 .shape = (8, 8)
#  G  .shape = (1, 8)     R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.997 0.986 0.959 0.936]
#  freq Hz   = [ 1.92 27.26 76.33 22.16]
#  sigma2    = [3.894 1.492 0.187 0.436]
#  obs noise R = [[0.212]]
#  dc index  = None
#
# AR: add freq = 205.74 Hz, add radius = 0.777, add sigma2 = 0.206
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.271013296855248), 'Q_sigma2': 'MLE'}
# Iteration 4 completed:
# <Osc object at 0x171ad04f0>
#  nstate   = 10    ncomp    = 5
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<3d00>, Osc(0)<3dc0>, Osc(0)<3af0>, Osc(0)<3d30>, Osc(0)<9df0>]
#  F  .shape = (10, 10)   Q  .shape = (10, 10)
#  mu0.shape = (10, 1)    S0 .shape = (10, 10)
#  G  .shape = (1, 10)    R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.998 0.985 0.962 0.993 0.881]
#  freq Hz   = [  1.92  32.51  77.07  20.3  176.32]
#  sigma2    = [3.022 1.037 0.194 0.466 0.165]
#  obs noise R = [[0.208]]
#  dc index  = None
#
# AR: add freq = 129.39 Hz, add radius = 0.770, add sigma2 = 0.221
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.271013296855248), 'Q_sigma2': 'MLE'}
# Iteration 5 completed:
# <Osc object at 0x171ad04f0>
#  nstate   = 12    ncomp    = 6
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<9f40>, Osc(0)<9ee0>, Osc(0)<9f10>, Osc(0)<9e80>, Osc(0)<9e50>, Osc(0)<9fa0>]
#  F  .shape = (12, 12)   Q  .shape = (12, 12)
#  mu0.shape = (12, 1)    S0 .shape = (12, 12)
#  G  .shape = (1, 12)    R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.998 0.987 0.965 0.993 0.884 0.905]
#  freq Hz   = [  1.93  32.81  74.31  20.22 182.98 120.55]
#  sigma2    = [2.76  0.798 0.191 0.523 0.135 0.184]
#  obs noise R = [[0.206]]
#  dc index  = None
#
# AR: add freq = 230.37 Hz, add radius = 0.789, add sigma2 = 0.113
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.271013296855248), 'Q_sigma2': 'MLE'}
# Iteration 6 completed:
# <Osc object at 0x171ad04f0>
#  nstate   = 14    ncomp    = 7
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<3d30>, Osc(0)<a0a0>, Osc(0)<a0d0>, Osc(0)<a100>, Osc(0)<a130>, Osc(0)<a190>, Osc(0)<a1c0>]
#  F  .shape = (14, 14)   Q  .shape = (14, 14)
#  mu0.shape = (14, 1)    S0 .shape = (14, 14)
#  G  .shape = (1, 14)    R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.998 0.988 0.965 0.993 0.886 0.916 0.829]
#  freq Hz   = [  1.92  32.98  73.82  20.12 176.09 117.37 205.51]
#  sigma2    = [2.667 0.704 0.189 0.586 0.109 0.156 0.086]
#  obs noise R = [[0.205]]
#  dc index  = None
#
# found another hg freq at knee_idx +1 (=5)
#  freqs: [  1.92596477  32.81044039  74.30780164  20.22396053 182.98297061
#  120.55085829]
# <Osc object at 0x179f79df0>
#  nstate   = 12    ncomp    = 6
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<3e50>, Osc(0)<3820>, Osc(0)<3dc0>, Osc(0)<3af0>, Osc(0)<3d00>, Osc(0)<a040>]
#  F  .shape = (12, 12)   Q  .shape = (12, 12)
#  mu0.shape = (12, 1)    S0 .shape = (12, 12)
#  G  .shape = (1, 12)    R  .shape = (1, 1)
#  y  .shape = None       Fs = 1024.0 Hz
#  damping a = [0.998 0.987 0.965 0.993 0.884 0.905]
#  freq Hz   = [  1.93  32.81  74.31  20.22 182.98 120.55]
#  sigma2    = [2.76  0.798 0.191 0.523 0.135 0.184]
#  obs noise R = [[0.206]]
#  dc index  = None
#
# channel 4
# {'channel': 4, 'knee_n_osc': np.int64(6), 'logL': np.float64(-24425.65323794187), 'freqs': array([  1.92596477,  32.81044039,  74.30780164,  20.22396053,
#        182.98297061, 120.55085829]), 'damping': array([0.99784674, 0.98744623, 0.96456095, 0.9929969 , 0.88396728,
#        0.90549209]), 'sigma2': array([2.76033374, 0.79826621, 0.19099963, 0.52275793, 0.1354069 ,
#        0.18351891]), 'obs_noise_R': array([[0.20637805]])}
# EM learning on the initial oscillator
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.2850269532098476), 'Q_sigma2': 'MLE'}
# Iteration 0 completed:
# <Osc object at 0x171af9760>
#  nstate   = 2     ncomp    = 1
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<9d30>]
#  F  .shape = (2, 2)     Q  .shape = (2, 2)
#  mu0.shape = (2, 1)     S0 .shape = (2, 2)
#  G  .shape = (1, 2)     R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.994]
#  freq Hz   = [1.71]
#  sigma2    = [6.841]
#  obs noise R = [[0.226]]
#  dc index  = None
#
# AR: add freq = 0.10 Hz, add radius = 0.739, add sigma2 = 0.112
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.2850269532098476), 'Q_sigma2': 'MLE'}
# Iteration 1 completed:
# <Osc object at 0x171af9760>
#  nstate   = 4     ncomp    = 2
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<2ee0>, Osc(0)<e790>]
#  F  .shape = (4, 4)     Q  .shape = (4, 4)
#  mu0.shape = (4, 1)     S0 .shape = (4, 4)
#  G  .shape = (1, 4)     R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.994 0.782]
#  freq Hz   = [1.72 0.12]
#  sigma2    = [6.745 0.107]
#  obs noise R = [[0.226]]
#  dc index  = None
#
# AR: add freq = 78.79 Hz, add radius = 0.720, add sigma2 = 0.166
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.2850269532098476), 'Q_sigma2': 'MLE'}
# Iteration 2 completed:
# <Osc object at 0x171af9760>
#  nstate   = 6     ncomp    = 3
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<0130>, Osc(0)<3970>, Osc(0)<3be0>]
#  F  .shape = (6, 6)     Q  .shape = (6, 6)
#  mu0.shape = (6, 1)     S0 .shape = (6, 6)
#  G  .shape = (1, 6)     R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.995 0.818 0.945]
#  freq Hz   = [ 1.8   0.14 85.52]
#  sigma2    = [6.055 0.102 0.18 ]
#  obs noise R = [[0.226]]
#  dc index  = None
#
# AR: add freq = 36.40 Hz, add radius = 0.804, add sigma2 = 0.221
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.2850269532098476), 'Q_sigma2': 'MLE'}
# Iteration 3 completed:
# <Osc object at 0x171af9760>
#  nstate   = 8     ncomp    = 4
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<3460>, Osc(0)<3400>, Osc(0)<3fa0>, Osc(0)<3730>]
#  F  .shape = (8, 8)     Q  .shape = (8, 8)
#  mu0.shape = (8, 1)     S0 .shape = (8, 8)
#  G  .shape = (1, 8)     R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.995 0.848 0.951 0.944]
#  freq Hz   = [ 1.82  0.17 80.57 39.62]
#  sigma2    = [5.626 0.098 0.198 0.218]
#  obs noise R = [[0.226]]
#  dc index  = None
#
# AR: add freq = 30.10 Hz, add radius = 0.791, add sigma2 = 0.201
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.2850269532098476), 'Q_sigma2': 'MLE'}
# Iteration 4 completed:
# <Osc object at 0x171af9760>
#  nstate   = 10    ncomp    = 5
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<eb20>, Osc(0)<7c40>, Osc(0)<7d00>, Osc(0)<7c70>, Osc(0)<7d60>]
#  F  .shape = (10, 10)   Q  .shape = (10, 10)
#  mu0.shape = (10, 1)    S0 .shape = (10, 10)
#  G  .shape = (1, 10)    R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.995 0.87  0.95  0.984 0.853]
#  freq Hz   = [ 1.8   0.19 80.42 30.69 35.3 ]
#  sigma2    = [5.137 0.095 0.223 0.236 0.189]
#  obs noise R = [[0.227]]
#  dc index  = None
#
# AR: add freq = 139.20 Hz, add radius = 0.738, add sigma2 = 0.229
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.2850269532098476), 'Q_sigma2': 'MLE'}
# Iteration 5 completed:
# <Osc object at 0x171af9760>
#  nstate   = 12    ncomp    = 6
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<7f10>, Osc(0)<7eb0>, Osc(0)<7ee0>, Osc(0)<7e80>, Osc(0)<7e50>, Osc(0)<7f70>]
#  F  .shape = (12, 12)   Q  .shape = (12, 12)
#  mu0.shape = (12, 1)    S0 .shape = (12, 12)
#  G  .shape = (1, 12)    R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.996 0.897 0.955 0.985 0.961 0.891]
#  freq Hz   = [  1.93   0.22  77.61  28.51  40.76 151.75]
#  sigma2    = [3.807 0.09  0.234 0.26  0.182 0.248]
#  obs noise R = [[0.222]]
#  dc index  = None
#
# AR: add freq = 206.64 Hz, add radius = 0.811, add sigma2 = 0.178
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.2850269532098476), 'Q_sigma2': 'MLE'}
# Iteration 6 completed:
# <Osc object at 0x171af9760>
#  nstate   = 14    ncomp    = 7
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<7d60>, Osc(0)<7070>, Osc(0)<70d0>, Osc(0)<70a0>, Osc(0)<7100>, Osc(0)<7160>, Osc(0)<7190>]
#  F  .shape = (14, 14)   Q  .shape = (14, 14)
#  mu0.shape = (14, 1)    S0 .shape = (14, 14)
#  G  .shape = (1, 14)    R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.997 0.926 0.958 0.99  0.984 0.914 0.89 ]
#  freq Hz   = [  1.87   0.28  75.61  19.92  35.31 132.2  192.63]
#  sigma2    = [2.936 0.086 0.243 0.289 0.188 0.209 0.146]
#  obs noise R = [[0.218]]
#  dc index  = None
#
# changed knee_idx from 0 to 2
# <Osc object at 0x171b0e790>
#  nstate   = 6     ncomp    = 3
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<3e20>, Osc(0)<3b20>, Osc(0)<3580>]
#  F  .shape = (6, 6)     Q  .shape = (6, 6)
#  mu0.shape = (6, 1)     S0 .shape = (6, 6)
#  G  .shape = (1, 6)     R  .shape = (1, 1)
#  y  .shape = None       Fs = 1024.0 Hz
#  damping a = [0.995 0.818 0.945]
#  freq Hz   = [ 1.8   0.14 85.52]
#  sigma2    = [6.055 0.102 0.18 ]
#  obs noise R = [[0.226]]
#  dc index  = None
#
# channel 5
# {'channel': 5, 'knee_n_osc': 3, 'logL': np.float64(-24512.548601311508), 'freqs': array([ 1.80311294,  0.1440841 , 85.52134044]), 'damping': array([0.99477866, 0.81828985, 0.94499341]), 'sigma2': array([6.05470803, 0.10228298, 0.1801182 ]), 'obs_noise_R': array([[0.22573311]])}
# EM learning on the initial oscillator
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.30507558287160064), 'Q_sigma2': 'MLE'}
# Iteration 0 completed:
# <Osc object at 0x179fa71c0>
#  nstate   = 2     ncomp    = 1
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<f100>]
#  F  .shape = (2, 2)     Q  .shape = (2, 2)
#  mu0.shape = (2, 1)     S0 .shape = (2, 2)
#  G  .shape = (1, 2)     R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.994]
#  freq Hz   = [1.55]
#  sigma2    = [7.114]
#  obs noise R = [[0.243]]
#  dc index  = None
#
# AR: add freq = 0.10 Hz, add radius = 0.808, add sigma2 = 0.092
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.30507558287160064), 'Q_sigma2': 'MLE'}
# Iteration 1 completed:
# <Osc object at 0x179fa71c0>
#  nstate   = 4     ncomp    = 2
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<9e20>, Osc(0)<0550>]
#  F  .shape = (4, 4)     Q  .shape = (4, 4)
#  mu0.shape = (4, 1)     S0 .shape = (4, 4)
#  G  .shape = (1, 4)     R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.994 0.828]
#  freq Hz   = [1.57 0.12]
#  sigma2    = [7.027 0.09 ]
#  obs noise R = [[0.243]]
#  dc index  = None
#
# AR: add freq = 162.01 Hz, add radius = 0.745, add sigma2 = 0.175
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.30507558287160064), 'Q_sigma2': 'MLE'}
# Iteration 2 completed:
# <Osc object at 0x179fa71c0>
#  nstate   = 6     ncomp    = 3
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<3a00>, Osc(0)<3610>, Osc(0)<3a60>]
#  F  .shape = (6, 6)     Q  .shape = (6, 6)
#  mu0.shape = (6, 1)     S0 .shape = (6, 6)
#  G  .shape = (1, 6)     R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.995 0.852 0.904]
#  freq Hz   = [1.76e+00 1.38e-01 1.60e+02]
#  sigma2    = [5.907 0.087 0.198]
#  obs noise R = [[0.237]]
#  dc index  = None
#
# AR: add freq = 100.86 Hz, add radius = 0.786, add sigma2 = 0.321
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.30507558287160064), 'Q_sigma2': 'MLE'}
# Iteration 3 completed:
# <Osc object at 0x179fa71c0>
#  nstate   = 8     ncomp    = 4
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<3d60>, Osc(0)<7df0>, Osc(0)<7d90>, Osc(0)<7ca0>]
#  F  .shape = (8, 8)     Q  .shape = (8, 8)
#  mu0.shape = (8, 1)     S0 .shape = (8, 8)
#  G  .shape = (1, 8)     R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.996 0.879 0.903 0.94 ]
#  freq Hz   = [  1.92   0.17 167.99  82.44]
#  sigma2    = [4.737 0.084 0.204 0.335]
#  obs noise R = [[0.235]]
#  dc index  = None
#
# AR: add freq = 31.53 Hz, add radius = 0.827, add sigma2 = 0.209
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.30507558287160064), 'Q_sigma2': 'MLE'}
# Iteration 4 completed:
# <Osc object at 0x179fa71c0>
#  nstate   = 10    ncomp    = 5
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<eb80>, Osc(0)<3610>, Osc(0)<3a00>, Osc(0)<3a60>, Osc(0)<4e20>]
#  F  .shape = (10, 10)   Q  .shape = (10, 10)
#  mu0.shape = (10, 1)    S0 .shape = (10, 10)
#  G  .shape = (1, 10)    R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.996 0.904 0.902 0.941 0.973]
#  freq Hz   = [  1.92   0.21 168.42  80.95  34.54]
#  sigma2    = [4.237 0.08  0.218 0.344 0.204]
#  obs noise R = [[0.235]]
#  dc index  = None
#
# AR: add freq = 20.39 Hz, add radius = 0.771, add sigma2 = 0.296
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.30507558287160064), 'Q_sigma2': 'MLE'}
# Iteration 5 completed:
# <Osc object at 0x179fa71c0>
#  nstate   = 12    ncomp    = 6
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<4f70>, Osc(0)<4eb0>, Osc(0)<4f40>, Osc(0)<4ee0>, Osc(0)<4dc0>, Osc(0)<4fd0>]
#  F  .shape = (12, 12)   Q  .shape = (12, 12)
#  mu0.shape = (12, 1)    S0 .shape = (12, 12)
#  G  .shape = (1, 12)    R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.996 0.925 0.899 0.941 0.983 0.875]
#  freq Hz   = [  1.9    0.27 168.31  80.63  27.72  24.33]
#  sigma2    = [3.877 0.078 0.235 0.357 0.213 0.252]
#  obs noise R = [[0.235]]
#  dc index  = None
#
# AR: add freq = 20.83 Hz, add radius = 0.766, add sigma2 = 0.298
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.30507558287160064), 'Q_sigma2': 'MLE'}
# Iteration 6 completed:
# <Osc object at 0x179fa71c0>
#  nstate   = 14    ncomp    = 7
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<6ca0>, Osc(0)<40d0>, Osc(0)<4100>, Osc(0)<4130>, Osc(0)<4160>, Osc(0)<41c0>, Osc(0)<41f0>]
#  F  .shape = (14, 14)   Q  .shape = (14, 14)
#  mu0.shape = (14, 1)    S0 .shape = (14, 14)
#  G  .shape = (1, 14)    R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.997 0.944 0.896 0.94  0.982 0.964 0.87 ]
#  freq Hz   = [  1.87   0.37 167.84  80.65  24.62  27.15  24.85]
#  sigma2    = [3.569 0.075 0.246 0.363 0.219 0.236 0.251]
#  obs noise R = [[0.235]]
#  dc index  = None
#
# changed knee_idx from 0 to 2
# found another hg freq at knee_idx +1 (=3)
#  freqs: [  1.91832809   0.16859806 167.993918    82.44282806]
# <Osc object at 0x171b0e580>
#  nstate   = 8     ncomp    = 4
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<7c70>, Osc(0)<7cd0>, Osc(0)<7e50>, Osc(0)<a250>]
#  F  .shape = (8, 8)     Q  .shape = (8, 8)
#  mu0.shape = (8, 1)     S0 .shape = (8, 8)
#  G  .shape = (1, 8)     R  .shape = (1, 1)
#  y  .shape = None       Fs = 1024.0 Hz
#  damping a = [0.996 0.879 0.903 0.94 ]
#  freq Hz   = [  1.92   0.17 167.99  82.44]
#  sigma2    = [4.737 0.084 0.204 0.335]
#  obs noise R = [[0.235]]
#  dc index  = None
#
# channel 6
# {'channel': 6, 'knee_n_osc': 4, 'logL': np.float64(-24509.78044184234), 'freqs': array([  1.91832809,   0.16859806, 167.993918  ,  82.44282806]), 'damping': array([0.99576328, 0.87934983, 0.90319479, 0.94016276]), 'sigma2': array([4.73654266, 0.08350101, 0.20426514, 0.33481019]), 'obs_noise_R': array([[0.23504816]])}
# EM learning on the initial oscillator
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.29677718333741787), 'Q_sigma2': 'MLE'}
# Iteration 0 completed:
# <Osc object at 0x179fe4040>
#  nstate   = 2     ncomp    = 1
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<42e0>]
#  F  .shape = (2, 2)     Q  .shape = (2, 2)
#  mu0.shape = (2, 1)     S0 .shape = (2, 2)
#  G  .shape = (1, 2)     R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.994]
#  freq Hz   = [1.44]
#  sigma2    = [7.482]
#  obs noise R = [[0.239]]
#  dc index  = None
#
# AR: add freq = 165.51 Hz, add radius = 0.773, add sigma2 = 0.249
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.29677718333741787), 'Q_sigma2': 'MLE'}
# Iteration 1 completed:
# <Osc object at 0x179fe4040>
#  nstate   = 4     ncomp    = 2
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<4f40>, Osc(0)<0220>]
#  F  .shape = (4, 4)     Q  .shape = (4, 4)
#  mu0.shape = (4, 1)     S0 .shape = (4, 4)
#  G  .shape = (1, 4)     R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.995 0.898]
#  freq Hz   = [  1.71 159.6 ]
#  sigma2    = [6.034 0.273]
#  obs noise R = [[0.233]]
#  dc index  = None
#
# AR: add freq = 96.41 Hz, add radius = 0.795, add sigma2 = 0.338
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.29677718333741787), 'Q_sigma2': 'MLE'}
# Iteration 2 completed:
# <Osc object at 0x179fe4040>
#  nstate   = 6     ncomp    = 3
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<42e0>, Osc(0)<9df0>, Osc(0)<9e20>]
#  F  .shape = (6, 6)     Q  .shape = (6, 6)
#  mu0.shape = (6, 1)     S0 .shape = (6, 6)
#  G  .shape = (1, 6)     R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.996 0.899 0.941]
#  freq Hz   = [  1.88 167.54  81.61]
#  sigma2    = [4.799 0.272 0.356]
#  obs noise R = [[0.231]]
#  dc index  = None
#
# AR: add freq = 29.90 Hz, add radius = 0.817, add sigma2 = 0.222
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.29677718333741787), 'Q_sigma2': 'MLE'}
# Iteration 3 completed:
# <Osc object at 0x179fe4040>
#  nstate   = 8     ncomp    = 4
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<a2b0>, Osc(0)<3610>, Osc(0)<3d60>, Osc(0)<3a60>]
#  F  .shape = (8, 8)     Q  .shape = (8, 8)
#  mu0.shape = (8, 1)     S0 .shape = (8, 8)
#  G  .shape = (1, 8)     R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.996 0.899 0.941 0.959]
#  freq Hz   = [  1.88 167.63  80.81  33.55]
#  sigma2    = [4.415 0.276 0.365 0.211]
#  obs noise R = [[0.231]]
#  dc index  = None
#
# AR: add freq = 21.61 Hz, add radius = 0.777, add sigma2 = 0.292
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.29677718333741787), 'Q_sigma2': 'MLE'}
# Iteration 4 completed:
# <Osc object at 0x179fe4040>
#  nstate   = 10    ncomp    = 5
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<8580>, Osc(0)<9e20>, Osc(0)<0f10>, Osc(0)<0040>, Osc(0)<0070>]
#  F  .shape = (10, 10)   Q  .shape = (10, 10)
#  mu0.shape = (10, 1)    S0 .shape = (10, 10)
#  G  .shape = (1, 10)    R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.996 0.898 0.94  0.983 0.877]
#  freq Hz   = [  1.86 167.81  80.88  26.81  25.36]
#  sigma2    = [3.991 0.287 0.379 0.218 0.25 ]
#  obs noise R = [[0.23]]
#  dc index  = None
#
# AR: add freq = 15.77 Hz, add radius = 0.748, add sigma2 = 0.495
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.29677718333741787), 'Q_sigma2': 'MLE'}
# Iteration 5 completed:
# <Osc object at 0x179fe4040>
#  nstate   = 12    ncomp    = 6
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<0250>, Osc(0)<01f0>, Osc(0)<0220>, Osc(0)<01c0>, Osc(0)<0130>, Osc(0)<02b0>]
#  F  .shape = (12, 12)   Q  .shape = (12, 12)
#  mu0.shape = (12, 1)    S0 .shape = (12, 12)
#  G  .shape = (1, 12)    R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.997 0.898 0.94  0.989 0.968 0.897]
#  freq Hz   = [  1.76 167.66  81.01  19.44  28.96  19.9 ]
#  sigma2    = [3.528 0.289 0.381 0.226 0.234 0.379]
#  obs noise R = [[0.23]]
#  dc index  = None
#
# AR: add freq = 124.94 Hz, add radius = 0.815, add sigma2 = 0.186
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.29677718333741787), 'Q_sigma2': 'MLE'}
# Iteration 6 completed:
# <Osc object at 0x179fe4040>
#  nstate   = 14    ncomp    = 7
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<0f10>, Osc(0)<0400>, Osc(0)<03d0>, Osc(0)<03a0>, Osc(0)<02e0>, Osc(0)<0340>, Osc(0)<0490>]
#  F  .shape = (14, 14)   Q  .shape = (14, 14)
#  mu0.shape = (14, 1)    S0 .shape = (14, 14)
#  G  .shape = (1, 14)    R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.998 0.895 0.949 0.995 0.979 0.987 0.932]
#  freq Hz   = [  1.56 181.61  75.21  12.75  30.13  18.8  127.61]
#  sigma2    = [2.419 0.263 0.364 0.246 0.226 0.331 0.182]
#  obs noise R = [[0.229]]
#  dc index  = None
#
# <Osc object at 0x179fb7ca0>
#  nstate   = 6     ncomp    = 3
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<4070>, Osc(0)<3a00>, Osc(0)<3400>]
#  F  .shape = (6, 6)     Q  .shape = (6, 6)
#  mu0.shape = (6, 1)     S0 .shape = (6, 6)
#  G  .shape = (1, 6)     R  .shape = (1, 1)
#  y  .shape = None       Fs = 1024.0 Hz
#  damping a = [0.996 0.899 0.941]
#  freq Hz   = [  1.88 167.54  81.61]
#  sigma2    = [4.799 0.272 0.356]
#  obs noise R = [[0.231]]
#  dc index  = None
#
# channel 7
# ...
#  mu0.shape = (6, 1)     S0 .shape = (6, 6)
#  G  .shape = (1, 6)     R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.995 0.901 0.939]
#  freq Hz   = [  2.15 165.28  82.1 ]
#  sigma2    = [4.872 0.299 0.401]
#  obs noise R = [[0.244]]
#  dc index  = None
#
# AR: add freq = 31.15 Hz, add radius = 0.822, add sigma2 = 0.215
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.3146197999402971), 'Q_sigma2': 'MLE'}
# Iteration 3 completed:
# <Osc object at 0x179fa7040>
#  nstate   = 8     ncomp    = 4
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<4d90>, Osc(0)<3d60>, Osc(0)<0220>, Osc(0)<0eb0>]
#  F  .shape = (8, 8)     Q  .shape = (8, 8)
#  mu0.shape = (8, 1)     S0 .shape = (8, 8)
#  G  .shape = (1, 8)     R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.995 0.898 0.939 0.954]
#  freq Hz   = [  2.15 164.79  81.28  34.9 ]
#  sigma2    = [4.461 0.321 0.416 0.206]
#  obs noise R = [[0.244]]
#  dc index  = None
#
# AR: add freq = 24.98 Hz, add radius = 0.791, add sigma2 = 0.245
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.3146197999402971), 'Q_sigma2': 'MLE'}
# Iteration 4 completed:
# <Osc object at 0x179fa7040>
#  nstate   = 10    ncomp    = 5
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<4280>, Osc(0)<89a0>, Osc(0)<f190>, Osc(0)<f130>, Osc(0)<8eb0>]
#  F  .shape = (10, 10)   Q  .shape = (10, 10)
#  mu0.shape = (10, 1)    S0 .shape = (10, 10)
#  G  .shape = (1, 10)    R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.996 0.895 0.938 0.982 0.874]
#  freq Hz   = [  2.12 164.33  81.19  27.9   28.17]
#  sigma2    = [4.025 0.347 0.431 0.211 0.217]
#  obs noise R = [[0.244]]
#  dc index  = None
#
# AR: add freq = 20.50 Hz, add radius = 0.763, add sigma2 = 0.321
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.3146197999402971), 'Q_sigma2': 'MLE'}
# Iteration 5 completed:
# <Osc object at 0x179fa7040>
#  nstate   = 12    ncomp    = 6
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<8f10>, Osc(0)<8f40>, Osc(0)<8fa0>, Osc(0)<f040>, Osc(0)<f0a0>, Osc(0)<f0d0>]
#  F  .shape = (12, 12)   Q  .shape = (12, 12)
#  mu0.shape = (12, 1)    S0 .shape = (12, 12)
#  G  .shape = (1, 12)    R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.996 0.893 0.938 0.986 0.957 0.865]
#  freq Hz   = [  2.06 163.46  81.06  22.12  33.18  24.11]
#  sigma2    = [3.659 0.364 0.435 0.219 0.206 0.27 ]
#  obs noise R = [[0.244]]
#  dc index  = None
#
# AR: add freq = 12.15 Hz, add radius = 0.741, add sigma2 = 0.730
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.3146197999402971), 'Q_sigma2': 'MLE'}
# Iteration 6 completed:
# <Osc object at 0x179fa7040>
#  nstate   = 14    ncomp    = 7
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<9ee0>, Osc(0)<f2b0>, Osc(0)<f220>, Osc(0)<f250>, Osc(0)<f1f0>, Osc(0)<f1c0>, Osc(0)<f100>]
#  F  .shape = (14, 14)   Q  .shape = (14, 14)
#  mu0.shape = (14, 1)    S0 .shape = (14, 14)
#  G  .shape = (1, 14)    R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.997 0.892 0.939 0.995 0.978 0.938 0.906]
#  freq Hz   = [  1.77 163.47  81.21  14.31  29.65  27.19  17.24]
#  sigma2    = [2.802 0.388 0.441 0.244 0.204 0.243 0.509]
#  obs noise R = [[0.244]]
#  dc index  = None
#
# <Osc object at 0x179ff4f40>
#  nstate   = 6     ncomp    = 3
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<a2b0>, Osc(0)<0f70>, Osc(0)<0fa0>]
#  F  .shape = (6, 6)     Q  .shape = (6, 6)
#  mu0.shape = (6, 1)     S0 .shape = (6, 6)
#  G  .shape = (1, 6)     R  .shape = (1, 1)
#  y  .shape = None       Fs = 1024.0 Hz
#  damping a = [0.995 0.901 0.939]
#  freq Hz   = [  2.15 165.28  82.1 ]
#  sigma2    = [4.872 0.299 0.401]
#  obs noise R = [[0.244]]
#  dc index  = None
#
# channel 8
# {'channel': 8, 'knee_n_osc': np.int64(3), 'logL': np.float64(-24919.154846334015), 'freqs': array([  2.14765928, 165.27827139,  82.1018099 ]), 'damping': array([0.99487132, 0.90074151, 0.93933494]), 'sigma2': array([4.87186711, 0.29850258, 0.40065747]), 'obs_noise_R': array([[0.24447856]])}
# EM learning on the initial oscillator
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.32483534577978185), 'Q_sigma2': 'MLE'}
# Iteration 0 completed:
# <Osc object at 0x179f33a60>
#  nstate   = 2     ncomp    = 1
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<b640>]
#  F  .shape = (2, 2)     Q  .shape = (2, 2)
#  mu0.shape = (2, 1)     S0 .shape = (2, 2)
#  G  .shape = (1, 2)     R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.99]
#  freq Hz   = [0.54]
#  sigma2    = [9.78]
#  obs noise R = [[0.268]]
#  dc index  = None
#
# AR: add freq = 159.14 Hz, add radius = 0.772, add sigma2 = 0.306
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.32483534577978185), 'Q_sigma2': 'MLE'}
# Iteration 1 completed:
# <Osc object at 0x179f33a60>
#  nstate   = 4     ncomp    = 2
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<f2e0>, Osc(0)<f040>]
#  F  .shape = (4, 4)     Q  .shape = (4, 4)
#  mu0.shape = (4, 1)     S0 .shape = (4, 4)
#  G  .shape = (1, 4)     R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.992 0.907]
#  freq Hz   = [  1.79 153.05]
#  sigma2    = [7.205 0.447]
#  obs noise R = [[0.26]]
#  dc index  = None
#
# AR: add freq = 98.68 Hz, add radius = 0.822, add sigma2 = 0.403
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.32483534577978185), 'Q_sigma2': 'MLE'}
# Iteration 2 completed:
# <Osc object at 0x179f33a60>
#  nstate   = 6     ncomp    = 3
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<0f40>, Osc(0)<04c0>, Osc(0)<0430>]
#  F  .shape = (6, 6)     Q  .shape = (6, 6)
#  mu0.shape = (6, 1)     S0 .shape = (6, 6)
#  G  .shape = (1, 6)     R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.994 0.898 0.94 ]
#  freq Hz   = [  2.22 163.57  85.8 ]
#  sigma2    = [5.314 0.505 0.477]
#  obs noise R = [[0.256]]
#  dc index  = None
#
# AR: add freq = 34.03 Hz, add radius = 0.831, add sigma2 = 0.238
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.32483534577978185), 'Q_sigma2': 'MLE'}
# Iteration 3 completed:
# <Osc object at 0x179f33a60>
#  nstate   = 8     ncomp    = 4
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<7280>, Osc(0)<0070>, Osc(0)<0040>, Osc(0)<40a0>]
#  F  .shape = (8, 8)     Q  .shape = (8, 8)
#  mu0.shape = (8, 1)     S0 .shape = (8, 8)
#  G  .shape = (1, 8)     R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.994 0.895 0.938 0.968]
#  freq Hz   = [  2.25 162.49  84.56  37.81]
#  sigma2    = [4.622 0.555 0.528 0.235]
#  obs noise R = [[0.256]]
#  dc index  = None
#
# AR: add freq = 25.01 Hz, add radius = 0.787, add sigma2 = 0.268
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.32483534577978185), 'Q_sigma2': 'MLE'}
# Iteration 4 completed:
# <Osc object at 0x179f33a60>
#  nstate   = 10    ncomp    = 5
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<f190>, Osc(0)<f280>, Osc(0)<f190>, Osc(0)<51c0>, Osc(0)<5100>]
#  F  .shape = (10, 10)   Q  .shape = (10, 10)
#  mu0.shape = (10, 1)    S0 .shape = (10, 10)
#  G  .shape = (1, 10)    R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.995 0.892 0.936 0.974 0.873]
#  freq Hz   = [  2.25 161.74  83.78  33.09  27.8 ]
#  sigma2    = [4.269 0.591 0.561 0.239 0.237]
#  obs noise R = [[0.255]]
#  dc index  = None
#
# AR: add freq = 23.69 Hz, add radius = 0.782, add sigma2 = 0.291
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.32483534577978185), 'Q_sigma2': 'MLE'}
# Iteration 5 completed:
# <Osc object at 0x179f33a60>
#  nstate   = 12    ncomp    = 6
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<5340>, Osc(0)<52e0>, Osc(0)<5310>, Osc(0)<52b0>, Osc(0)<5250>, Osc(0)<53a0>]
#  F  .shape = (12, 12)   Q  .shape = (12, 12)
#  mu0.shape = (12, 1)    S0 .shape = (12, 12)
#  G  .shape = (1, 12)    R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.995 0.891 0.936 0.982 0.947 0.87 ]
#  freq Hz   = [  2.16 161.14  83.08  25.64  31.12  27.24]
#  sigma2    = [3.91  0.609 0.578 0.244 0.224 0.254]
#  obs noise R = [[0.255]]
#  dc index  = None
#
# AR: add freq = 22.64 Hz, add radius = 0.775, add sigma2 = 0.297
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.32483534577978185), 'Q_sigma2': 'MLE'}
# Iteration 6 completed:
# <Osc object at 0x179f33a60>
#  nstate   = 14    ncomp    = 7
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<b640>, Osc(0)<5550>, Osc(0)<54f0>, Osc(0)<5520>, Osc(0)<54c0>, Osc(0)<5490>, Osc(0)<53d0>]
#  F  .shape = (14, 14)   Q  .shape = (14, 14)
#  mu0.shape = (14, 1)    S0 .shape = (14, 14)
#  G  .shape = (1, 14)    R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.996 0.889 0.936 0.994 0.974 0.938 0.855]
#  freq Hz   = [  1.78 161.63  83.37  14.72  33.01  30.51  26.38]
#  sigma2    = [3.145 0.644 0.601 0.261 0.222 0.234 0.255]
#  obs noise R = [[0.255]]
#  dc index  = None
#
# <Osc object at 0x17a0cf040>
#  nstate   = 6     ncomp    = 3
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<0eb0>, Osc(0)<0550>, Osc(0)<0220>]
#  F  .shape = (6, 6)     Q  .shape = (6, 6)
#  mu0.shape = (6, 1)     S0 .shape = (6, 6)
#  G  .shape = (1, 6)     R  .shape = (1, 1)
#  y  .shape = None       Fs = 1024.0 Hz
#  damping a = [0.994 0.898 0.94 ]
#  freq Hz   = [  2.22 163.57  85.8 ]
#  sigma2    = [5.314 0.505 0.477]
#  obs noise R = [[0.256]]
#  dc index  = None
#
# channel 9
# {'channel': 9, 'knee_n_osc': np.int64(3), 'logL': np.float64(-25811.225629959445), 'freqs': array([  2.21687618, 163.56710604,  85.79781033]), 'damping': array([0.99357707, 0.89799701, 0.9396311 ]), 'sigma2': array([5.31422919, 0.50526354, 0.47657006]), 'obs_noise_R': array([[0.25595062]])}
# EM learning on the initial oscillator
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.4243226214355519), 'Q_sigma2': 'MLE'}
# Iteration 0 completed:
# <Osc object at 0x179d6f220>
#  nstate   = 2     ncomp    = 1
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<0520>]
#  F  .shape = (2, 2)     Q  .shape = (2, 2)
#  mu0.shape = (2, 1)     S0 .shape = (2, 2)
#  G  .shape = (1, 2)     R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.992]
#  freq Hz   = [4.83e-05]
#  sigma2    = [13.711]
#  obs noise R = [[0.351]]
#  dc index  = None
#
# AR: add freq = 155.55 Hz, add radius = 0.783, add sigma2 = 0.501
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.4243226214355519), 'Q_sigma2': 'MLE'}
# Iteration 1 completed:
# <Osc object at 0x179d6f220>
#  nstate   = 4     ncomp    = 2
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<5130>, Osc(0)<5400>]
#  F  .shape = (4, 4)     Q  .shape = (4, 4)
#  mu0.shape = (4, 1)     S0 .shape = (4, 4)
#  G  .shape = (1, 4)     R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.995 0.911]
#  freq Hz   = [-1.48e-05  1.40e+02]
#  sigma2    = [8.647 0.975]
#  obs noise R = [[0.336]]
#  dc index  = None
#
# AR: add freq = 88.21 Hz, add radius = 0.858, add sigma2 = 0.434
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.4243226214355519), 'Q_sigma2': 'MLE'}
# Iteration 2 completed:
# <Osc object at 0x179d6f220>
#  nstate   = 6     ncomp    = 3
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<5190>, Osc(0)<fc40>, Osc(0)<7df0>]
#  F  .shape = (6, 6)     Q  .shape = (6, 6)
#  mu0.shape = (6, 1)     S0 .shape = (6, 6)
#  G  .shape = (1, 6)     R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.996 0.897 0.951]
#  freq Hz   = [ -0.66 150.06  83.36]
#  sigma2    = [6.191 1.155 0.525]
#  obs noise R = [[0.329]]
#  dc index  = None
#
# AR: add freq = 31.97 Hz, add radius = 0.825, add sigma2 = 0.299
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.4243226214355519), 'Q_sigma2': 'MLE'}
# Iteration 3 completed:
# <Osc object at 0x179d6f220>
#  nstate   = 8     ncomp    = 4
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<5100>, Osc(0)<3d60>, Osc(0)<3730>, Osc(0)<3610>]
#  F  .shape = (8, 8)     Q  .shape = (8, 8)
#  mu0.shape = (8, 1)     S0 .shape = (8, 8)
#  G  .shape = (1, 8)     R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.997 0.896 0.948 0.971]
#  freq Hz   = [ -0.89 150.85  83.74  35.73]
#  sigma2    = [5.323 1.195 0.588 0.295]
#  obs noise R = [[0.328]]
#  dc index  = None
#
# AR: add freq = 208.21 Hz, add radius = 0.851, add sigma2 = 0.314
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.4243226214355519), 'Q_sigma2': 'MLE'}
# Iteration 4 completed:
# <Osc object at 0x179d6f220>
#  nstate   = 10    ncomp    = 5
#  nchannel = 1     ntime    = 10240
#  nmodel   = 1
#  components = [Osc(0)<40a0>, Osc(0)<5280>, Osc(0)<5400>, Osc(0)<e250>, Osc(0)<e280>]
#  F  .shape = (10, 10)   Q  .shape = (10, 10)
#  mu0.shape = (10, 1)    S0 .shape = (10, 10)
#  G  .shape = (1, 10)    R  .shape = (1, 1)
#  y  .shape = (1, 10240) Fs = 1024.0 Hz
#  damping a = [0.997 0.922 0.951 0.983 0.927]
#  freq Hz   = [ -0.95 129.71  78.    27.53 186.55]
#  sigma2    = [4.562 0.807 0.574 0.311 0.295]
#  obs noise R = [[0.324]]
#  dc index  = None
#
# AR: add freq = 231.14 Hz, add radius = 0.807, add sigma2 = 0.213
# Prior input parameters: {'R_hyperparameter': 0.1, 'Q_hyperparameter': None, 'R_sigma2': np.float64(0.4243226214355519), 'Q_sigma2': 'MLE'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 16
#      13 for ch in range(n_channels):
#      14 # -run IterOsc for the channel -
#      15     io1 = IterOsc(eeg[:, ch], eeg_sr, noise_start=None, osc_range=7)
# ---> 16     io1.iterate(freq_res=1, plot_fit=False, verbose=True)
#      18     # find knee index
#      19     ll_vec = io1.ll
#
# File ~/Library/Python/3.9/lib/python/site-packages/somata/oscillator_search/iter_osc.py:154, in IterativeOscillatorModel.iterate(self, freq_res, keep_param, reiterate, sigma2_method, freq_hp, R_hp, Q_hp, R_sigma2, Q_sigma2, no_priors, track_params, plot_fit, verbose)
#     152 em_params = []  # store the oscillator parameters throughout EM iterations
#     153 for _ in range(50):
# --> 154     _ = o1.m_estimate(**o1.dejong_filt_smooth(EM=True), priors=priors, keep_param=self.keep_param)
#     155     if track_params:
#     156         em_params.append(o1.copy(drop_y=True))
#
# File ~/Library/Python/3.9/lib/python/site-packages/somata/basic_models/ssm.py:924, in StateSpaceModel.dejong_filt_smooth(self, y, R_weights, return_dict, EM, skip_interp, seterr)
#     921     old_settings = np.seterr(**seterr)
#     923 y = self.y if y is None else y
# --> 924 x_t_n, P_t_n, P_t_tmin1_n, logL, x_t_t, P_t_t, K_t, x_t_tmin1, P_t_tmin1, fy_t_interp = djkalman(
#     925     F=self.F, Q=self.Q, mu0=self.mu0, S0=self.S0, G=self.G, R=self.R, y=y, R_weights=R_weights,
#     926     skip_interp=skip_interp)
#     928 if seterr is not None:
#     929     # noinspection PyUnboundLocalVariable
#     930     np.seterr(**old_settings)
#
# File ~/Library/Python/3.9/lib/python/site-packages/somata/exact_inference/dp_func.py:445, in djkalman(F, Q, mu0, S0, G, R, y, R_weights, skip_interp)
#     442     P_t_tmin1[:, :, ii+1] = FP @ L_t[:, :, ii].T + Q
#     444     # Innovation form of the log likelihood
# --> 445     logL[ii-1] = -(qlog2pi + logdet(D_t) + e_t[:, ii].T @ invD_t[:, :, ii] @ e_t[:, ii]) / 2
#     447 # remove the extra t=T+1 time point created
#     448 x_t_tmin1 = x_t_tmin1[:, :-1]
#
# KeyboardInterrupt:

# %%
#parralel somata 

from joblib import Parallel, delayed
import gc

def process_channel(ch, eeg_data, eeg_sr):
    # --- run IterOsc for the channel ---
    # Note: Pass only the specific channel data to the function to save memory
    io1 = IterOsc(eeg_data, eeg_sr, noise_start=None, osc_range=7)
    io1.iterate(freq_res=1, plot_fit=False, verbose=False)

    ll_vec = io1.ll
    knee_idx = get_knee(ll_vec)
    best_model_for_ch = io1.get_knee_osc()

    # --- Rescue Logic (Knee 0) ---
    if knee_idx == 0:
        for i, model in enumerate(io1.fitted_osc[1:], start=1):
            if 70 <= model.freq[-1] <= 170:
                best_model_for_ch = model
                knee_idx = i
                break
        if knee_idx == 0:
            knee_idx = 2
        print(f'changed knee_idx from 0 to {knee_idx}')

    # --- Look Ahead Logic (HG search) ---
    if knee_idx + 1 < len(io1.fitted_osc):
        next_model = io1.fitted_osc[knee_idx+1]
        last_freq_next = next_model.freq[-1]
        if 70 <= last_freq_next <= 170:
            freq_diffs = np.abs(best_model_for_ch.freq - last_freq_next)
            if np.all(freq_diffs > 5):
                knee_idx += 1
                best_model_for_ch = next_model
                print(f'found another hg freq at knee_idx +1 (={knee_idx})')

    #print("channel", ch)
    #print("freqs", best_model_for_ch.freq)
    
    returns = {
        'channel': ch,
        'knee_n_osc': knee_idx + 1,
        'logL': ll_vec[knee_idx],
        'freqs': best_model_for_ch.freq,
        'damping': best_model_for_ch.a,
        'sigma2': best_model_for_ch.sigma2, 
        'obs_noise_R': best_model_for_ch.R 
    }
    del io1
    del best_model_for_ch
    gc.collect()
    return returns

# --- Execution ---
n_channels = eeg.shape[1]
print(n_channels)

# Run with limited jobs and tqdm to keep the kernel awake
from tqdm.auto import tqdm
eeg_sr = 1024

results_list = Parallel(n_jobs=4)( # Only 4 jobs to save RAM
    delayed(process_channel)(ch, eeg[:, ch], eeg_sr) 
    for ch in tqdm(range(n_channels), desc="Running SOMATA")
)


# Convert list of results back to a dictionary for your saving format
channel_results = {i: res for i, res in enumerate(results_list)}

# Save
path_somata = '/Users/lisa/Documents/DSAI_year2/SingleWordProductionDutch-1/somata'
np.save(os.path.join(path_somata, f'{participant}_somata_results.npy'), channel_results)
# Out:
# 127
# Running SOMATA:   0%|          | 0/127 [00:00<?, ?it/s]

# %%
#average frequency template constructor by finding clusters in somata results

from sklearn.neighbors import KernelDensity
from scipy.signal import find_peaks


def plot_density_template(results_dict, template_freqs, s, dens, all_freqs):
    plt.figure(figsize=(12, 6))
    
    # plot the smooth KDE density curve
    plt.plot(s, dens, color='black', lw=2, label='Kernel Density (KDE)')
    plt.fill_between(s.flatten(), dens, alpha=0.2, color='gray')
    
    # plot the individual frequencies found by SOMATA (the blue vertical lines)
    plt.vlines(all_freqs, ymin=0, ymax=dens.max()*0.05, color='blue', alpha=0.3, label='SOMATA Freqs')
    
    # mark the final chosen template frequencies
    for f in template_freqs:
        # Get density value at this frequency to place the marker
        idx = np.argmin(np.abs(s - f))
        plt.plot(f, dens[idx], "ro", markersize=8)
        plt.annotate(f"{f:.1f}Hz", (f, dens[idx]), textcoords="offset points", 
                     xytext=(0,10), ha='center', fontweight='bold', color='red')
    
    plt.title('Frequency Cluster Analysis & Template Selection', fontsize=14)
    plt.xlabel('Frequency (Hz)', fontsize=12)
    plt.ylabel('Density (Probability)', fontsize=12)
    plt.xlim(0, 170)
    plt.grid(alpha=0.3)
    plt.legend()
    plt.show()


def build_density_template(results_dict, nr_osc = 3, min_hg_osc=2):
    all_freqs = []
    for ch, data in results_dict.items():
        if any(70 <= f <= 170 for f in data['freqs']):
            all_freqs.extend(data['freqs'])

    print(f'nr of frequencies in somata results in total: {len(all_freqs)}')
    #print(f'all frequencies found: {sorted(all_freqs)}')
    # Reshape for sklearn
    X = np.array(all_freqs).reshape(-1, 1)
    
    # 1. Fit KDE (bandwidth=3 means it treats freqs within ~3-5Hz as 'together')
    kde = KernelDensity(kernel='gaussian', bandwidth=2).fit(X)
    
    # 2. Evaluate density across the spectrum (0 to 170 Hz)
    s = np.linspace(0, 170, 1000).reshape(-1, 1)
    log_dens = kde.score_samples(s)
    dens = np.exp(log_dens)
    
    # 3. Find peaks in the density
    peaks, _ = find_peaks(dens, distance=5) # distance ensures peaks are at least 5Hz apart
    peak_freqs = s[peaks].flatten()

    print(f'peak_freqs: {peak_freqs}')
    

    # For non HG, pick the top nr_osc strongest peaks
    # Sort peaks by their density (height)
    peaks_sorted = sorted(peak_freqs, key=lambda f: dens[np.argmin(np.abs(s-f))], reverse=True)
    template = set(peaks_sorted[:nr_osc])

    
    #if less hg peaks included then minimal:
    if len([f for f in template if 70 <= f <= 170]) <min_hg_osc:
        hg_peaks = [f for f in peak_freqs if 70 <= f <= 170]
        # Sort HG peaks by their density (height)
        hg_peaks_sorted = sorted(hg_peaks, key=lambda f: dens[np.argmin(np.abs(s-f))], reverse=True)
        template.update(hg_peaks_sorted[:min_hg_osc])

    plot_density_template(results_dict, template, s, dens, all_freqs)
    
    return sorted(list(template))

'''
# Run it
refined_template = build_density_template(channel_results)
print(f"Refined Template Freqs: {refined_template}")
'''
# Out:
# '\n# Run it\nrefined_template = build_density_template(channel_results)\nprint(f"Refined Template Freqs: {refined_template}")\n'

# %%
def get_template_parameters(results_dict, template_freqs, window=7):
    final_a = []
    final_s = []
    
    for target_f in template_freqs:
        window = 2 if target_f < 10 else 7
        matching_as = []
        matching_ss = []
        
        for ch, data in results_dict.items():
            # Extract lists from the dictionary
            ch_freqs = np.array(data['freqs'])
            ch_as = np.array(data['damping'])
            ch_ss = np.array(data['sigma2'])
            
            # Find indices where channel frequency is close to the template peak
            matches = np.where(np.abs(ch_freqs - target_f) <= window)[0]
            
            if len(matches) > 0:
                matching_as.extend(ch_as[matches])
                matching_ss.extend(ch_ss[matches])
        
        # Calculate mean for this peak. Fallback to sensible defaults if no match.
        if matching_as:
            final_a.append(np.mean(matching_as))
            final_s.append(np.mean(matching_ss))
        else:
            # Default values if a cluster has no close contributors (shouldn't happen)
            final_a.append(0.98) 
            final_s.append(0.5)
            
    return final_a, final_s


'''
# --- RUNNING THE WHOLE CHAIN ---
template_freqs = build_density_template(channel_results)
template_a, template_s = get_template_parameters(channel_results, template_freqs)

# Calculate average R from all channels analyzed (but not necessarily used for peaks!)
all_Rs = [data['obs_noise_R'] for data in channel_results.values()]
avg_R = np.mean(all_Rs)

print("\n--- Final Consensus Template ---")
for i, f in enumerate(template_freqs):
    print(f"Freq: {f:6.2f} Hz | a: {template_a[i]:.4f} | s: {template_s[i]:.4f}")
print(f"Average Observation Noise R: {avg_R:.2e}")
'''
# Out:
# '\n# --- RUNNING THE WHOLE CHAIN ---\ntemplate_freqs = build_density_template(channel_results)\ntemplate_a, template_s = get_template_parameters(channel_results, template_freqs)\n\n# Calculate average R from all channels analyzed (but not necessarily used for peaks!)\nall_Rs = [data[\'obs_noise_R\'] for data in channel_results.values()]\navg_R = np.mean(all_Rs)\n\nprint("\n--- Final Consensus Template ---")\nfor i, f in enumerate(template_freqs):\n    print(f"Freq: {f:6.2f} Hz | a: {template_a[i]:.4f} | s: {template_s[i]:.4f}")\nprint(f"Average Observation Noise R: {avg_R:.2e}")\n'

# %%
#for a single participant
#first: run somata for each channel and save the results in participant_somata_results
participant = "sub-07"
somata_results = np.load(os.path.join(path_somata,f'{participant}_somata_results.npy'),allow_pickle=True).item()

#gather all channels that have a peak in hg range (that we thus want to use for our base osc template)    
has_hg_osc = set()
for idx, data in somata_results.items():
    if any(70 <= f <= 170 for f in data['freqs']):
        #has_hg_osc.add(int(data['channel']))
        has_hg_osc.add(idx)

hg_subset_results = {idx: somata_results[idx] for idx in has_hg_osc}
template_freqs = build_density_template(hg_subset_results, nr_osc = 3, min_hg_osc=2)
template_a, template_s = get_template_parameters(hg_subset_results, template_freqs) 

print("\n--- Final Consensus Template ---")
for i, f in enumerate(template_freqs):
    print(f"Freq: {f:6.2f} Hz | a: {template_a[i]:.4f} | s: {template_s[i]:.4f}")
# Out:
# nr of frequencies in somata results in total: 480
# peak_freqs: [  1.7017017   13.27327327  27.73773774  61.26126126  73.34334334
#   84.06406406  96.14614615 103.46346346 116.22622623 124.05405405
#  144.81481481 151.11111111 163.02302302]
# --- Final Consensus Template ---
# Freq:   1.70 Hz | a: 0.9799 | s: 4.0698
# Freq:  27.74 Hz | a: 0.9824 | s: 0.7680
# Freq:  84.06 Hz | a: 0.9030 | s: 0.3698
# Freq: 163.02 Hz | a: 0.8783 | s: 0.2847

# %%
participant = "sub-06"

somata_results = np.load(os.path.join(path_somata,f'{participant}_somata_results.npy'),allow_pickle=True).item()

#gather all channels that have a peak in hg range (that we thus want to use for our base osc template)    
has_hg_osc = set()
for idx, data in somata_results.items():
    if any(70 <= f <= 170 for f in data['freqs']):
        #has_hg_osc.add(int(data['channel']))
        has_hg_osc.add(idx)

hg_subset_results = {idx: somata_results[idx] for idx in has_hg_osc}
template_freqs = build_density_template(hg_subset_results)
template_a, template_s = get_template_parameters(hg_subset_results, template_freqs) 
print(len(has_hg_osc))
print("\n--- Final Consensus Template ---")
for i, f in enumerate(template_freqs):
    print(f"Freq: {f:6.2f} Hz | a: {template_a[i]:.4f} | s: {template_s[i]:.4f}")
# Out:
# peak_freqs: [  1.36136136   5.61561562  20.42042042  36.75675676  56.83683684
#   71.98198198  84.91491491  98.6986987  104.31431431 113.16316316
#  118.26826827 124.9049049  148.04804805]
# 12
#
# --- Final Consensus Template ---
# Freq:   1.36 Hz | a: 0.9971 | s: 6.6737
# Freq:   5.62 Hz | a: 0.9989 | s: 4.9174
# Freq:  71.98 Hz | a: 0.9633 | s: 0.3388
# Freq: 104.31 Hz | a: 0.9161 | s: 0.1949
# found another hg freq at knee_idx +1 (=5)
# changed knee_idx from 0 to 3
# changed knee_idx from 0 to 2
# found another hg freq at knee_idx +1 (=3)
# changed knee_idx from 0 to 2
# found another hg freq at knee_idx +1 (=3)
# found another hg freq at knee_idx +1 (=3)
# changed knee_idx from 0 to 2
# found another hg freq at knee_idx +1 (=3)
# found another hg freq at knee_idx +1 (=3)
# changed knee_idx from 0 to 2
# changed knee_idx from 0 to 3
# found another hg freq at knee_idx +1 (=2)
# found another hg freq at knee_idx +1 (=3)
# found another hg freq at knee_idx +1 (=3)
# changed knee_idx from 0 to 2
# changed knee_idx from 0 to 2
# found another hg freq at knee_idx +1 (=3)
# changed knee_idx from 0 to 2
# found another hg freq at knee_idx +1 (=3)
# changed knee_idx from 0 to 2
# found another hg freq at knee_idx +1 (=4)
# changed knee_idx from 0 to 2
# found another hg freq at knee_idx +1 (=3)
# found another hg freq at knee_idx +1 (=3)
# found another hg freq at knee_idx +1 (=3)
# found another hg freq at knee_idx +1 (=5)
# changed knee_idx from 0 to 4
# found another hg freq at knee_idx +1 (=5)
# changed knee_idx from 0 to 3
# changed knee_idx from 0 to 2
# found another hg freq at knee_idx +1 (=4)
# changed knee_idx from 0 to 2
# changed knee_idx from 0 to 2
# found another hg freq at knee_idx +1 (=3)
# changed knee_idx from 0 to 2
# found another hg freq at knee_idx +1 (=4)
# found another hg freq at knee_idx +1 (=3)
# found another hg freq at knee_idx +1 (=4)
# found another hg freq at knee_idx +1 (=3)
# changed knee_idx from 0 to 2
# found another hg freq at knee_idx +1 (=3)
# found another hg freq at knee_idx +1 (=5)
# changed knee_idx from 0 to 2
# found another hg freq at knee_idx +1 (=3)
# changed knee_idx from 0 to 2
# found another hg freq at knee_idx +1 (=3)
# changed knee_idx from 0 to 2
# found another hg freq at knee_idx +1 (=3)
# changed knee_idx from 0 to 2
# changed knee_idx from 0 to 2
# changed knee_idx from 0 to 2
# changed knee_idx from 0 to 2
# found another hg freq at knee_idx +1 (=3)
# found another hg freq at knee_idx +1 (=4)
# changed knee_idx from 0 to 3
# changed knee_idx from 0 to 2
# found another hg freq at knee_idx +1 (=3)
# found another hg freq at knee_idx +1 (=4)
# changed knee_idx from 0 to 2
# changed knee_idx from 0 to 2
# changed knee_idx from 0 to 3
# found another hg freq at knee_idx +1 (=4)
# found another hg freq at knee_idx +1 (=5)
# found another hg freq at knee_idx +1 (=3)
# found another hg freq at knee_idx +1 (=5)
# found another hg freq at knee_idx +1 (=4)
# changed knee_idx from 0 to 2
# changed knee_idx from 0 to 2
# changed knee_idx from 0 to 4
# found another hg freq at knee_idx +1 (=5)
# found another hg freq at knee_idx +1 (=3)
# found another hg freq at knee_idx +1 (=3)
# found another hg freq at knee_idx +1 (=3)
# changed knee_idx from 0 to 2
# found another hg freq at knee_idx +1 (=3)
# changed knee_idx from 0 to 3
# changed knee_idx from 0 to 2
# changed knee_idx from 0 to 2
# changed knee_idx from 0 to 2
# changed knee_idx from 0 to 2
# found another hg freq at knee_idx +1 (=3)
# found another hg freq at knee_idx +1 (=6)
# changed knee_idx from 0 to 2
# found another hg freq at knee_idx +1 (=3)

# %%
# Build initParams list for all channels
participant = "sub-07"
initParams_list = []
for ch in range(n_channels):
    if ch in has_hg_osc:
        initParams = {
            "freqs": somata_results[ch]['freqs'],
            "Fs": eeg_sr,
            "ampVec": somata_results[ch]['damping'],
            "sigmaFreqs": somata_results[ch]['sigma2'],
            "sigmaObs": 1,
            "windowSize": 2000,
            "lowFreqBand": None
        }
    else:
        initParams = {
            "freqs": template_freqs,
            "Fs": eeg_sr,
            "ampVec": template_a,
            "sigmaFreqs": template_s,
            "sigmaObs": 1,
            "windowSize": 2000,
            "lowFreqBand": None
        }
    initParams_list.append(initParams)

run_extract_features(participant, initParams_list, SSPE=True)
# Out:
# Starting parallel SSPE extraction for 127 channels...
# extracted features

# %%
#specparam peak detection

for ch in top_channels:
    # take psd
    freqs, psd = welch(eeg[:, ch], fs=eeg_sr, nperseg=eeg_sr*2)
    
    # initialize and fit SpecParam model
    fm = SpectralModel(peak_width_limits=[2, 8], aperiodic_mode='knee')
    fm.report(freqs, psd, [0, 250], plt_log=False)
    result = fm.results

    print("channel: ", ch)
    print(result.get_results().peak_fit) #first column are the peak frequencies
    print(result.get_results().metrics)
# Out:
# /Users/lisa/Library/Python/3.9/lib/python/site-packages/specparam/data/data.py:292: RuntimeWarning: specparam fit warning - skipping frequency == 0, as this causes a problem with fitting.
#   warn(msg, category=RuntimeWarning)
# /Users/lisa/Library/Python/3.9/lib/python/site-packages/specparam/data/data.py:292: RuntimeWarning: specparam fit warning - skipping frequency == 0, as this causes a problem with fitting.
#   warn(msg, category=RuntimeWarning)
# ==================================================================================================
#
#                                        POWER SPECTRUM MODEL
#
#                        The model was fit with the 'spectral_fit' algorithm
#               Model was fit to the 0-250 Hz frequency range with 0.50 Hz resolution
#
#                                 Aperiodic Parameters ('knee' mode)
#                                      (offset, knee, exponent)
#                                      4.8897, 25.7055, 2.8889
#
#                          Peak Parameters ('gaussian' mode) 1 peaks found
#                                 CF:  55.87, PW:   0.72, BW:   4.24
#
#                                           Model metrics:
#                                      error (mae) is 0.1817
#                                   gof (rsquared) is 0.9219
#
# ==================================================================================================
# channel:  50
# [[55.87154762  0.72055277  2.12137003]]
# {'error_mae': np.float64(0.18168225397051144), 'gof_rsquared': np.float64(0.9219091435777452)}
# ==================================================================================================
#
#                                        POWER SPECTRUM MODEL
#
#                        The model was fit with the 'spectral_fit' algorithm
#               Model was fit to the 0-250 Hz frequency range with 0.50 Hz resolution
#
#                                 Aperiodic Parameters ('knee' mode)
#                                      (offset, knee, exponent)
#                                       4.6647, 5.9790, 2.8529
#
#                          Peak Parameters ('gaussian' mode) 1 peaks found
#                                 CF:  27.12, PW:   0.70, BW:   8.00
#
#                                           Model metrics:
#                                      error (mae) is 0.1813
#                                   gof (rsquared) is 0.9273
#
# ==================================================================================================
# channel:  8
# [[27.11779933  0.70502587  3.99999992]]
# {'error_mae': np.float64(0.18128730950146338), 'gof_rsquared': np.float64(0.9273456657263243)}
# ==================================================================================================
#
#                                        POWER SPECTRUM MODEL
#
#                        The model was fit with the 'spectral_fit' algorithm
#               Model was fit to the 0-250 Hz frequency range with 0.50 Hz resolution
#
#                                 Aperiodic Parameters ('knee' mode)
#                                      (offset, knee, exponent)
#                                      4.9924, 30.2292, 2.9501
#
#                          Peak Parameters ('gaussian' mode) 5 peaks found
#                                 CF:  39.16, PW:   0.81, BW:   8.00
#                                 CF:  55.72, PW:   0.81, BW:   4.19
#                                 CF:  63.53, PW:   0.57, BW:   7.05
#                                 CF:  71.94, PW:   0.65, BW:   4.08
#                                 CF:  78.32, PW:   0.59, BW:   8.00
#
#                                           Model metrics:
#                                      error (mae) is 0.1823
#                                   gof (rsquared) is 0.9341
#
# ==================================================================================================
# channel:  51
# [[39.15784619  0.80723978  4.        ]
#  [55.71932971  0.77182431  2.09276792]
#  [63.5326682   0.56903236  3.52483168]
#  [71.94246807  0.4539993   2.04199126]
#  [78.32176384  0.58556269  3.99999636]]
# {'error_mae': np.float64(0.1822942971485589), 'gof_rsquared': np.float64(0.9340524075073445)}
# ==================================================================================================
#
#                                        POWER SPECTRUM MODEL
#
#                        The model was fit with the 'spectral_fit' algorithm
#               Model was fit to the 0-250 Hz frequency range with 0.50 Hz resolution
#
#                                 Aperiodic Parameters ('knee' mode)
#                                      (offset, knee, exponent)
#                                       4.5477, 6.4576, 2.8382
#
#                          Peak Parameters ('gaussian' mode) 3 peaks found
#                                 CF:  76.09, PW:   0.70, BW:   8.00
#                                 CF:  90.19, PW:   0.70, BW:   8.00
#                                 CF: 103.37, PW:   0.51, BW:   8.00
#
#                                           Model metrics:
#                                      error (mae) is 0.1876
#                                   gof (rsquared) is 0.9185
#
# ==================================================================================================
# channel:  101
# [[ 76.08932091   0.7004748    4.        ]
#  [ 90.1872264    0.70013314   4.        ]
#  [103.36989196   0.50365794   4.        ]]
# {'error_mae': np.float64(0.18756588075857086), 'gof_rsquared': np.float64(0.9184947050427934)}
# ==================================================================================================
#
#                                        POWER SPECTRUM MODEL
#
#                        The model was fit with the 'spectral_fit' algorithm
#               Model was fit to the 0-250 Hz frequency range with 0.50 Hz resolution
#
#                                 Aperiodic Parameters ('knee' mode)
#                                      (offset, knee, exponent)
#                                      5.3047, 79.3802, 3.2081
#
#                          Peak Parameters ('gaussian' mode) 5 peaks found
#                                 CF:  29.18, PW:   0.43, BW:   8.00
#                                 CF:  40.73, PW:   0.56, BW:   6.64
#                                 CF:  47.35, PW:   0.73, BW:   2.00
#                                 CF:  58.23, PW:   0.75, BW:   8.00
#                                 CF:  70.96, PW:   0.54, BW:   8.00
#
#                                           Model metrics:
#                                      error (mae) is 0.1795
#                                   gof (rsquared) is 0.9427
#
# ==================================================================================================
# channel:  52
# [[29.17882574  0.42945151  3.9999999 ]
#  [40.72824455  0.54994271  3.31758065]
#  [47.34530282  0.64712287  1.        ]
#  [58.22883795  0.74557532  3.99999693]
#  [70.96050836  0.53815195  4.        ]]
# {'error_mae': np.float64(0.17945995468051434), 'gof_rsquared': np.float64(0.942703355178105)}
# /Users/lisa/Library/Python/3.9/lib/python/site-packages/specparam/data/data.py:292: RuntimeWarning: specparam fit warning - skipping frequency == 0, as this causes a problem with fitting.
#   warn(msg, category=RuntimeWarning)
# /Users/lisa/Library/Python/3.9/lib/python/site-packages/specparam/data/data.py:292: RuntimeWarning: specparam fit warning - skipping frequency == 0, as this causes a problem with fitting.
#   warn(msg, category=RuntimeWarning)
# /Users/lisa/Library/Python/3.9/lib/python/site-packages/specparam/data/data.py:292: RuntimeWarning: specparam fit warning - skipping frequency == 0, as this causes a problem with fitting.
#   warn(msg, category=RuntimeWarning)

# %%
#print specparam results

result = fm.results
print(result.n_peaks)
print(result.get_results().peak_fit) #first column are the peak frequencies
print(result.get_results().metrics)
# Out:
# 5
# [[29.17882574  0.42945151  3.9999999 ]
#  [40.72824455  0.54994271  3.31758065]
#  [47.34530282  0.64712287  1.        ]
#  [58.22883795  0.74557532  3.99999693]
#  [70.96050836  0.53815195  4.        ]]
# {'error_mae': np.float64(0.17945995468051434), 'gof_rsquared': np.float64(0.942703355178105)}

# %%
Best channel correlation and the channels peak frequencies
Sub-01
6              Unknown
56    ctx_lh_S_central
5              Unknown
47             Unknown
35             Unknown

Specparam:
6: 8.22
56:  78.18, 180
5:  6.98, 184           
47: 19.69 and 5 freqs > 200           
35: 63.5  

Somata:
6: [4.51] (99, 60, 41, 143), -31703
56:  [ 4.8  23.44](63, 30),  -32211
5: [6.31 1.38](60), -30140            
47: [ 4.03 19.16](65), -19989           
35: [ 6.76  1.9  30.35 63.16], (75, 106) -31151

Decision: 63, 78, 106         

Sub-02
channel: [101  57 108 106 105] ,
 region:  101    Right-Cerebral-White-Matter
57                         Unknown
108          ctx_rh_S_temporal_sup
106    Right-Cerebral-White-Matter
105    Right-Cerebral-White-Matter

Specparam:
channel 101: 83.03578904, 203.50002168
channel 57: 7.16, 13.50, 23.14, 203.33, 218.05
Channel 108: 217
Channel 106: 15.00, 202.74, 236.90
Channel 105: 243.68

Somata:
101: [14.89  0.98  7.42 31.38 72.03], -24231
57: [  7.98   0.63 182.72], -27324
108: [ 7.02 14.33  1.26 27.81] (61/ 56&103), -23208
106: [ 1.07  9.4  22.74] (61), -22234
105: [ 8.56  0.84 21.09] (64), -22057

Decision: 61, 72, 83, 103


Sub-03
Top 5 HG–speech correlated channels: [ 49  48  47  46 101]
with correlations:  [ 0.59024707  0.55861946  0.4307882   0.27109708 -0.24473377]
channel: 49 , region:  Unknown
channel: 48 , region:  ctx_rh_S_circular_insula_inf
channel: 47 , region:  Unknown
channel: 46 , region:  ctx_rh_S_circular_insula_inf
channel: 101 , region:  ctx_lh_G_temp_sup-Lateral

Specparam:
49: 69.3, 104.5, 127.1
48: 232.3
101: 161.5, 168.2, 174

Somata:
49: [ 0.96 13.09 77.05 31.04], -23832
48: [ 1.1  14.91 73.39 32.76], -24799
47: [ 1.35 22.69 67.21] (100), -24629
46: [0.01 67.56 22.68 11.22] (105), -23435
101: [ 0.27 60.76] (85,93) -31203

Decision: 68, 77, 105, 127

Sub-04
Top 5 HG–speech correlated channels: [ 30 108  31  32  36]
with correlations:  [0.52072519 0.39362911 0.38413352 0.34447387 0.31686988]
channel: 30 , region:  Unknown
channel: 108 , region:  ctx_rh_S_central
channel: 31 , region:  ctx_rh_G_pariet_inf-Supramar
channel: 32 , region:  ctx_rh_G_pariet_inf-Supramar
channel: 36 , region:  ctx_rh_Lat_Fis-post

Specparam:
channel 36: [66.79270399  0.54388763  4.]
No peaks found at the other channels

Somata:
30: [ 1.18 13.23 62.74 30.18], -24740
108: [ 2.04 17.31 59.96 37.36], -25215
31: [ 1.76 15.33 62.36 34.46], -25328
32:  [ 1.54  8.96 62.54 33.51 17.86], -23201
36: [ 1.83 14.7  54.2  84.35 34.44], -25446

Decision: 63, 84

Sub-05
Top 5 HG–speech correlated channels: [47 45 44 46 35]
with correlations:  [0.35066116 0.30894677 0.3043469  0.30161759 0.2710452 ]
channel: 47 , region:  ctx_rh_G_temporal_middle
channel: 45 , region:  ctx_rh_G_temporal_middle
channel: 44 , region:  ctx_rh_S_temporal_sup
channel: 46 , region:  ctx_rh_G_temporal_middle
channel: 35 , region:  Right-Cerebral-White-Matter

Specparam:
channel 45: 13.13, 20.11, 24.82, 100.21
channel 46: 12.84, 20.06, 24.50

Somata:
47: [0.18 193 115], -28650
45: [ 0.18 13.38] (22, 100, 180), -27187 
44: [ 0.18 12.71 25.95] (96, 169), -26791 
46: [0.19] (172, 13), -28011
35: [0.17], --29811

Decision: 25(?),100, 170


sub-06:
specparam
channel: 101 , region: ctx_rh_S_circular_insula_inf 
peaks: 76.08932091, 90.1872264, 103.36989196 Hz
{'error_mae': np.float64(0.18756588075857086), 'gof_rsquared': np.float64(0.9184947050427934)}

channel: 26 , region: ctx_lh_G_temp_sup-G_T_transv 
34.90829998, 224.96144074 Hz
{'error_mae': np.float64(0.18699603313551444), 'gof_rsquared': np.float64(0.9382922883142746)}

channel: 8 , region: Left-Cerebral-White-Matter
27.11779933
{'error_mae': np.float64(0.18128730950146338), 'gof_rsquared': np.float64(0.9273456657263243)}

channel:  100 , region: ctx_rh_S_circular_insula_inf,
64.90356669, 94.50000047
{'error_mae': np.float64(0.1802419288513362), 'gof_rsquared': np.float64(0.928559491874099)}

channel:  98 , region: ctx_rh_S_circular_insula_inf
54.27216366, 59.62707486, 64.20271514, 66.75155186, 71.83471434, 81.23954138, 85.2493639, 88.87505882, 97.29788934
{'error_mae': np.float64(0.17750625561836164), 'gof_rsquared': np.float64(0.9335202524220202)}

somata:
101: [1.95] (78, 61 In later iterations)
26: [ 1.09  6.82 18.85 41.21]
8: [ 1.    6.51 25.34 55.64]
100: [1.95] (1, 64, 41, 51 in later iterations)
98: [1.69] (6, 61, 50 in later iterations)

For channels 101, 100 and 98 model chose iteration 0 as best, because Log-likelihood briefly decreases at iteration 1 before improving. so those latter freqs I put  in the brackets

[64, 76, 90, 103] seem most informative frequencies (note, they all come from channels in ctx_rh_S_circular_insula_inf)



Sub-07:
specparam
channel: 96 , region:  ctx_lh_S_temporal_transverse
No peaks
{'error_mae': np.float64(0.1771620753451968), 'gof_rsquared': np.float64(0.8765308196252938)}
channel: 95 , region:  Left-Cerebral-White-Matter
No peaks
{'error_mae': np.float64(0.1677550224145677), 'gof_rsquared': np.float64(0.8815019679305702)}
channel: 94 , region:  Left-Cerebral-White-Matter
No peaks
{'error_mae': np.float64(0.17463185712443077), 'gof_rsquared': np.float64(0.8721652763231073)}
channel: 97 , region:  ctx_lh_S_temporal_transverse
160.77252024 Hz
{'error_mae': np.float64(0.1789235662843417), 'gof_rsquared': np.float64(0.8776777660670632)}
channel: 98 , region:  ctx_lh_G_temp_sup-Plan_tempo
140.00001662 Hz
{'error_mae': np.float64(0.17396662648965322), 'gof_rsquared': np.float64(0.8735891888809086)}

Somata model: 
Channel 96:  [ 2.19 18.62 77.71 36.81]
Channel 95: [ 2.08 19.62 74.86 38.41]
Channel 94: [  1.54  11.57  71.41  38.59  23.86 122.98 190.8 ]
Channel 97: [3.]
Channel 98: [2.82]

decision: use 77 (is in ch 95 and 96 of somata model) and 140 (ch 98 from spacparam). both informative for speech.
can experiment with adding 2 and 19 


Sub-08: 
specparam:
All top 5 channels in Left-Cerebral-White-Matter
And all peak frequencies >200 or <20 Hz

somata:
Channel 22    Left-Cerebral-White-Matter
logL: -21864, freqs: [ 1.57 13.44 28.69] (75)

Channel 31    Left-Cerebral-White-Matter
logL: -23011, freqs: [9.91 0.76] (65)

Channel 24    Left-Cerebral-White-Matter
logL: -21800, freqs: [ 1.02 12.01 66.04 29.79]

Channel 5     Left-Cerebral-White-Matter
logL: -22658, freqs: [ 5.42 17.62] (71)

Channel 7     Left-Cerebral-White-Matter
logL: -22456, freqs: [ 7.6  18.39  0.94] (82)

decision: 66, 75


Sub-09:
specparam:
all peak frequencies >170 or <15 Hz

Somata:
channel: 90 , region:  Left-Cerebral-White-Matter
[1.67] (63, 55, 125)

channel: 89 , region:  Left-Cerebral-White-Matter
[0.98] - no HGA peaks, and logL only decreased

channel: 91 , region:  ctx_lh_S_central
[1.75] (60)

channel: 6 , region:  Left-Cerebral-White-Matter
[  2.09 281.18 140.4  207.91]

channel: 7 , region:  ctx_lh_G_orbital
[ -1.36 208.62 129.45]

Decision: [60, 125] Hz


Sub-10
Top 5 HG–speech correlated channels: [33 32 34 35 36]
with correlations:  [0.55811939 0.54847478 0.48608983 0.40804694 0.37206639]
channel: 33 , region:  Right-Cerebral-White-Matter
channel: 32 , region:  ctx_rh_Lat_Fis-post
channel: 34 , region:  ctx_rh_G_temp_sup-G_T_transv
channel: 35 , region:  ctx_rh_G_temp_sup-Plan_tempo
channel: 36 , region:  ctx_rh_G_temp_sup-Plan_tempo

In the raw multitaper spectogram I could visually see multiple burst of a few seconds at ~110 Hz

Specparam:
channel 33: 93.26300761, 110.18012996 
channel 32: 92.67805208, 103.95464473, 111.84238554 
channel 34: 110.23393933

Somata:
33: [  2.3   20.74 106.06  59.62], logL -22946
32:  [  2.24  22.17 100.58  57.4 ], logL  -24265
34: [  0.93  25.72  10.37 104.05  61.64], logL -20715
35: [  0.85  10.99  57.69 101.72  30.69], logL -19502
36: [ 0.84 10.45 73.95 29.42], logL -19905

Decision: 60, 92, 105
